# %%
from Functions.RorschIA_functions_07_04 import raw_text_response_eval as eval

file_path = input("Copy and paste the path of the text doc.\n\n")

with open(file_path, "r") as f:
    text = f.read()

evaluation = eval(text)
# Out:
# Additional info not found
# Figure_1
#
# Coordination Found!
# Coordination Found!
# Response 1:  Some kind of beetle with big wings, or maybe some kind of frog.
# Noun Phrase(s): ['Some kind of beetle with big wings', 'maybe some kind of frog']
# Content: ['A', 'A']
# Determinant: ['Ma', 'FMp']
#
# Response 2:  Some kind of iking mask with four eyes.
# Noun Phrase(s): Some kind of iking mask with four eyes
# Content: Hd
# Determinant: F
#
# Response 3:  Some kind of silhouette.
# Noun Phrase(s): Some kind of silhouette
# Content: Sc
# Determinant: F
#
# Coordination Found!
# Coordination Found!
# Response 4:  A small figure with an open mouth that looks surprised and its reflection there.
# Noun Phrase(s): ['A small figure with an open mouth that looks surprised', 'its reflection there']
# Content: ['(H)', 'A']
# Determinant: ['Ma', 'F']
#
# Figure_2
#
# Coordination Found!
# Coordination Found!
# Coordination Found!
# Coordination Found!
# Response 1:  Two characters in the process of making contact or fighting because thereâ€™s blood or a leg that has been cut off.
# Noun Phrase(s): ['Two characters in the process of making contact', 'thereâ€ ™ s', 'Two characters in the process of making contact or fighting because thereâ€ ™ s blood', 'a leg that has been cut off']
# Content: ['Sc', 'A', 'Sc', 'Ad']
# Determinant: ['F', 'F', 'F', 'F']
#
# Response 2:  Lungs.
# Noun Phrase(s): Lungs
# Content: An
# Determinant: FY
#
# Coordination Found!
# Coordination Found!
# Response 3:  A rooster head with the crest Fighter plane, glider, jet engine fire; here too it could be a larger one sending missiles Trunk men, perhaps irrational or espÃ¨ces de chenilles with a big belly.
# Noun Phrase(s): ['A rooster', 'espÃ¨ces de chenilles with a big belly']
# Content: ['A', 'Id']
# Determinant: ['F', 'F']
#
# Figure_3
#
# Response 1:  Two strangely shaped guitars with twisted necks.
# Noun Phrase(s): Two strangely shaped guitars with twisted necks
# Content: H
# Determinant: Mp
#
# Response 2:  Again, two figures face to face, strangely constituted, like Picasso.
# Noun Phrase(s): two figures
# Content: H
# Determinant: FC
#
# Coordination Found!
# Coordination Found!
# Coordination Found!
# Coordination Found!
# Response 3:  Or two figures that are one and the same.
# Noun Phrase(s): ['no meaningful NP found', 'two figures that are one', 'Or two figures that are one', 'no meaningful NP found']
# Content: ['A', 'A', '(H)', 'A']
# Determinant: ['F', 'Ma', 'FMp', 'F']
#
# Coordination Found!
# Coordination Found!
# Response 4:  Two species of missile or torpedo.
# Noun Phrase(s): ['Two species of missile', 'torpedo']
# Content: ['H', 'A']
# Determinant: ['Mp', 'F']
#
# Coordination Found!
# Coordination Found!
# Response 5:  Lungs or a butterfly.
# Noun Phrase(s): ['Lungs', 'a butterfly']
# Content: ['An', 'A']
# Determinant: ['FY', 'F']
#
# Coordination Found!
# Coordination Found!
# Response 6:  Just the part of an old man with his cane or an embryo.
# Noun Phrase(s): ['Just the part of an old man with his cane', 'an embryo']
# Content: ['Sc', 'A']
# Determinant: ['F', 'F']
#
# Response 7:  A espÃ¨ce de grosse bÃªte, on voit lâ€™intÃ©rie de son corps, Les mandibules.
# Noun Phrase(s): A espÃ¨ce de grosse bÃªte on voit
# Content: Ay
# Determinant: F
#
# Figure_4
#
# Coordination Found!
# Coordination Found!
# Response 1:  I see yet another bizarre creature, a colossus, with wings and strange legs.
# Noun Phrase(s): ['a colossus with wings', 'strange legs']
# Content: ['Hx', 'Hd, Hh']
# Determinant: ['Ma', 'Mp, VF']
#
# Response 2:  Two figures under a kind of burka.
# Noun Phrase(s): Two figures under a kind of burka
# Content: H
# Determinant: Ma
#
# Response 3:  The fly's head (film).
# Noun Phrase(s): The fly 's head (film)
# Content: (Hd)
# Determinant: F
#
# Coordination Found!
# Coordination Found!
# Coordination Found!
# Coordination Found!
# Response 4:  Baby crocodile head or pig head since thereâ€™s no ear or maybe a mole, some kind of proboscis.
# Noun Phrase(s): ['Baby crocodile head', 'pig head since thereâ€ ™', 'Baby crocodile head or pig head since thereâ€ ™', 'maybe a mole some kind of proboscis']
# Content: ['(Hd)', '(Hd)', '(Hd)', 'Sc']
# Determinant: ['Mp', 'Mp', 'Mp', 'F']
#
# Figure_5
#
# Coordination Found!
# Coordination Found!
# Response 1:  I also see a sort of mix between a bat and a snail, there the legs are a bit strange.
# Noun Phrase(s): ['mix', 'the legs']
# Content: ['A', 'Hd']
# Determinant: ['F', 'Mp']
#
# Response 2:  Otherwise, I donâ€™t see anything else.
# Noun Phrase(s): no meaningful NP found
# Content: None
# Determinant: None
#
# Response 3:  Maybe two heads of characters in very small, They are back to back.
# Noun Phrase(s): characters
# Content: A
# Determinant: F
#
# Response 4:  The ACDC guitarist: his head with his hair.
# Noun Phrase(s): The ACDC guitarist : his head with his hair
# Content: Id
# Determinant: F
#
# Figure_6
#
# Response 1:  A rather odd dragonfly with half-destroyed wings.
# Noun Phrase(s): half - destroyed wings
# Content: (A)
# Determinant: Ma
#
# Coordination Found!
# Coordination Found!
# Response 2:  LÃ, the jaw of a beast with hooks inside its mouth, but thereâ€™s no eye so maybe itâ€™s a carnivorous plant.
# Noun Phrase(s): ['LÃ the jaw of a beast with hooks inside its mouth', 'thereâ€']
# Content: ['Id', 'A']
# Determinant: ['F', 'F']
#
# Response 3:  The sandman (in Spiderman) reverting to human form.
# Noun Phrase(s): The sandman (in Spiderman) reverting to human form
# Content: Na
# Determinant: F
#
# Response 4:  Otherwise thatâ€™s all I see.
# Noun Phrase(s): thatâ€
# Content: A
# Determinant: F
#
# Coordination Found!
# Coordination Found!
# Coordination Found!
# Coordination Found!
# Response 5:  Or lungs that are hidden right there or some kind of flageolet seeds.
# Noun Phrase(s): ['no meaningful NP found', 'lungs that are hidden right there', 'Or lungs that are hidden right there', 'some kind of flageolet seeds']
# Content: ['A', 'An', 'An', 'Sc']
# Determinant: ['F', 'F', 'F', 'F']
#
# Coordination Found!
# Coordination Found!
# Response 6:  Or some kind of figure with something to leap on.
# Noun Phrase(s): ['no meaningful NP found', 'some kind of figure with something to leap on']
# Content: ['A', 'Na']
# Determinant: ['F', 'Ma']
#
# Response 7:  Finally, maybe itâ€™s some kind of alien angel that goes to an island because it doesnâ€™t have wings.
# Noun Phrase(s): itâ€ ™
# Content: A
# Determinant: F
#
# Response 8:  It comes down that way so finally itâ€™s maybe a child that will come into the world.
# Noun Phrase(s): ™ s
# Content: A
# Determinant: F
#
# Figure_7
#
# Response 1:  Two espÃ¨ces dâ€™hippocampes with a trunk here; theyâ€™re connected the two by something thatâ€™s there; they donâ€™t look frozen because thereâ€™re stalactites, like perhaps prehistoric animals that have been frozen.
# Noun Phrase(s): Two espÃ¨ces
# Content: H, Xy
# Determinant: CF
#
# Coordination Found!
# Coordination Found!
# Response 2:  Or else you can see espÃ¨ces de personnages with chainsaw-like arms trying to get closer.
# Noun Phrase(s): ['no meaningful NP found', 'espÃ¨ces de personnages with chainsaw - like arms']
# Content: ['A', '(H)']
# Determinant: ['F', 'F']
#
# Response 3:  Prussian soldiers with spikes on their helmets.
# Noun Phrase(s): Prussian soldiers with spikes on their helmets
# Content: Id
# Determinant: F
#
# Response 4:  LÃ on peut voir une espÃ¨ce de tÃªte avec un groin mais vu quâ€™ il y a une proÃ©minence Ã§a peut être le bouffon du roi.
# Noun Phrase(s): LÃ on peut voir une espÃ¨ce de tÃªte avec un groin mais vu quâ€
# Content: Ay
# Determinant: F
#
# Response 5:  If you integrate the white, you can see a mask.
# Noun Phrase(s): no meaningful NP found
# Content: None
# Determinant: None
#
# Coordination Found!
# Coordination Found!
# Coordination Found!
# Coordination Found!
# Response 6:  A Mayan weapon; or perhaps not a weapon, a Mayan cult object or a species of mushroom.
# Noun Phrase(s): ['A Mayan weapon ;', 'perhaps not a weapon a Mayan cult object', 'A Mayan weapon ; or perhaps not a weapon a Mayan cult object', 'a species of mushroom']
# Content: ['A', 'A', 'A', 'Bt']
# Determinant: ['F', 'F', 'F', 'F']
#
# Figure_8
#
# Response 1:  A microscope view with just the right dyes.
# Noun Phrase(s): A microscope view with just the right dyes
# Content: A
# Determinant: F
#
# Response 2:  Two species of insect foraging on whatâ€™s there.
# Noun Phrase(s): Two species of insect foraging on whatâ€ ™ s there
# Content: A
# Determinant: F
#
# Response 3:  A fly head with something dripping from it (orange).
# Noun Phrase(s): A fly head with something dripping from it (orange)
# Content: Id
# Determinant: F
#
# Response 4:  Vocal cords (green lines).
# Noun Phrase(s): Vocal cords (green lines)
# Content: A
# Determinant: F
#
# Response 5:  A character with some sort of antennae, disregarding the vocal cords.
# Noun Phrase(s): A character with some sort of antennae disregarding the vocal cords
# Content: A
# Determinant: FD
#
# Coordination Found!
# Coordination Found!
# Coordination Found!
# Coordination Found!
# Response 6:  Two chameleons climbing a mountain; it doesnâ€™t look like theyâ€™re shaking hands; thereâ€™s a transaction or something: theyâ€™re giving money or recharging energy.
# Noun Phrase(s): ['Two chameleons climbing a mountain ; it doesnâ€ ™ t', 'theyâ€', 'Two chameleons climbing a mountain ; it doesnâ€ ™ t', 'no meaningful NP found']
# Content: ['Hd', 'A', 'Hd', 'A']
# Determinant: ['F', 'F', 'F', 'F']
#
# Figure_9
#
# Response 1:  Two species of deformed creatures approaching.
# Noun Phrase(s): Two species of deformed creatures approaching
# Content: H
# Determinant: Mp
#
# Response 2:  Two nostrils, perhaps a skull hidden by everything else.
# Noun Phrase(s): Two nostrils perhaps a skull hidden by everything else
# Content: H
# Determinant: Mp
#
# Coordination Found!
# Coordination Found!
# Response 3:  A ghost's head partly hidden by the rest, or some kind of magnetic field.
# Noun Phrase(s): ["A ghost 's head partly hidden by the rest", 'some kind of magnetic field']
# Content: ['(Hd)', 'Sc']
# Determinant: ['F', 'F']
#
# Coordination Found!
# Coordination Found!
# Response 4:  Two islands or two countries that are a reflection of each other (green).
# Noun Phrase(s): ['Two islands', 'two countries that are a reflection of each other (green)']
# Content: ['H, Xy', 'An']
# Determinant: ['CF', "FC'"]
#
# Response 5:  A piece of Parma ham (pink).
# Noun Phrase(s): A piece of Parma ham (pink)
# Content: Sc
# Determinant: F
#
# Response 6:  Some kind of roots, like the Sepultura logo (orange lines) Some kind of symbiotic matter that fuses together.
# Noun Phrase(s): Some kind of roots like the Sepultura logo (orange lines) Some kind of symbiotic matter that fuses together
# Content: Sc
# Determinant: F
#
# Response 7:  A character with wings (green).
# Noun Phrase(s): A character with wings (green)
# Content: Hx
# Determinant: Ma
#
# Figure_10
#
# Response 1:  It's quite contemporary art, like Miro.
# Noun Phrase(s): quite contemporary art like Miro
# Content: (H)
# Determinant: Mp
#
# Response 2:  Two species of little bugs fighting over what's in the middle (black).
# Noun Phrase(s): Two species of little bugs fighting over what 's in the middle (black)
# Content: Sc
# Determinant: F
#
# Coordination Found!
# Coordination Found!
# Response 3:  Octopuses or alien policemen trying to separate them (blue).
# Noun Phrase(s): ['Octopuses', 'alien policemen']
# Content: ['A', 'An']
# Determinant: ['F', 'FC']
#
# Coordination Found!
# Coordination Found!
# Response 4:  Two little suns or comets (yellow).
# Noun Phrase(s): ['Two little suns', 'comets (yellow)']
# Content: ['H, Xy', 'A']
# Determinant: ['CF', 'F']
#
# Coordination Found!
# Coordination Found!
# Coordination Found!
# Coordination Found!
# Response 5:  Two caterpillars or the letter Omega with a spider or tuning fork in the box (green).
# Noun Phrase(s): ['Two', 'the letter Omega with a spider', 'Two caterpillars or the letter Omega with a spider', 'the box (green)']
# Content: ['H, Xy', 'Id', '(A)', 'A']
# Determinant: ['CF', 'F', 'FMp', 'F']
#
# Response 6:  Two kinds of embryos spitting out blue matter (pink).
# Noun Phrase(s): Two kinds of embryos
# Content: H
# Determinant: Mp
#
# Coordination Found!
# Coordination Found!
# Response 7:  Two species of ants with a black+yellow flame), they are catching the two things that are there (orange) or the Ghostrider motorcycle.
# Noun Phrase(s): ['ants with a black+yellow flame', 'the Ghostrider motorcycle']
# Content: ['Id', 'A']
# Determinant: ['F', 'F']
#
# Coordination Found!
# Coordination Found!
# Response 8:  I also see two eyes with weird mouths: the green one isnâ€™t the horns, the blue one the mouth, the gray one an electric razor or some kind of sonic screwdriver.
# Noun Phrase(s): ['weird mouths', 'some kind of sonic screwdriver']
# Content: ['A', 'Sc']
# Determinant: ['F', 'F']
#
# Coordination Found!
# Coordination Found!
# Response 9:  Two figures with a blue ponpon are liquefying, perhaps made of skin and air (pink).
# Noun Phrase(s): ['Two figures with a blue ponpon', 'air (pink)']
# Content: ['H', 'A']
# Determinant: ['F', 'F']
#
# Response 10:  The two ants, theyâ€™re going to try to put on a hat to plug them up so they donâ€™t swell up.
# Noun Phrase(s): The two ants theyâ€ ™
# Content: H
# Determinant: FC
#
# Coordination Found!
# Coordination Found!
# Coordination Found!
# Coordination Found!
# Response 11:  Two back or hair brushes or a slightly odd compass (orange).
# Noun Phrase(s): ['Two back', 'hair brushes', 'Two back or hair brushes', 'a slightly odd compass (orange)']
# Content: ['H', 'A', '(A)', 'A']
# Determinant: ['Mp', 'F', 'FMp', 'F']
#
# Response 12:  Finally, the two caterpillars have their astral projections coming out of their bodies.
# Noun Phrase(s): the two caterpillars
# Content: H
# Determinant: FC
#
# Coordination Found!
# Coordination Found!
# Response 13:  Two people supporting each other so they donâ€™t lose their balance and fall over (central blue).
# Noun Phrase(s): ['Two people supporting each other so they donâ€ ™ t', 'central blue']
# Content: ['H', 'A']
# Determinant: ['Ma', 'F']
