# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import scipy
import re
import json
import spacy
import os
import requests
import sys
import deepl
import collections
import spacy

import pandas as pd
import numpy as np

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# Structuring the text:
#
# The following functions provide a way to get raw text and categorize it into the different figure numbers, the different sentences the subject spoke for each figure as well as storing information like the special position markers associated with the specific sentences they refer to.

# %%
raw_text = '''

I/ @ ^ Une sorte de coléoptère avec des grandes ailes
ou ça peut être une sorte de grenouille.
V Une sorte de masque Viking avec quatre yeux.
Une sorte de silhouette.
Un petit personnage avec  une bouche ouverte qui a l’air surpris
et son reflet là.


II/ V Deux personnages en train d’établir un contact ou
un combat parce qu’il y a du sang ou une jambe qui a été coupée.
Des poumons.
^ Une tête de coq avec la crête
Avion de chasse, planeur, feu des réacteurs ;
là aussi ça peut être un plus grand qui envoie des missiles
Des hommes troncs, peut-être irrationnels
ou des espèces de chenilles avec un gros ventre.

III/ ^ Deux guitares avec des formes bizarres, le manche
tordu.
Encore deux personnages face à face bizarrement constitués,
comme du Picasso. Ou deux personnages qui font qu’un.
Deux espèces de missiles ou de torpilles.
Des poumons
ou un papillon.
V Juste la partie d’un vieillard avec sa canne
ou un embryon.
Une espèce de grosse bête, on voit l’intérieur de son corps,
Les mandibules.

IV/ V Je vois encore une sorte de créature bizarre, un colosse,
Avec  les ailes là et des pattes étranges.
^ Deux personnages sous une espèce de burka.
V La tête de la mouche (film).
> Tête de bébé crocodile ou de cochon vu qu’il y a pas d’oreille
ou peut-être une taupe, une sorte de trompe.

V/ ^ Je vois aussi une sorte de mélange entre une chauve-souris
et un escargot, là les pattes sont un peu étranges.
@ Sinon là je vois rien d’autre.
Peut-être deux têtes de personnages en tout petit,
Ils sont dos à dos.
Le guitariste d’ACDC : sa tête avec ses cheveux.

VI/ @ ^ Une libellule un peu bizarre avec des ailes
à demi détruites.
Là, la mâchoire d’une bête avec des crochets à l’intérieur
de sa bouche, mais y a pas d’œil alors c’est peut-être
une plante carnivore.
L’homme sable (dans Spiderman) en train de reprendre
forme humaine.
Sinon c’est tout ce que je vois.
Ou encore des poumons qui sont cachés juste là
ou des sortes de graines de flageolets.
Ou là une sorte de personnage avec quelque chose
pour faire des bonds.
Finalement, c’est peut-être une sorte d’ange
extraterrestre qui va dans une île parce qu’il y a des ailes.
Il descend par là donc finalement c’est peut-être
un enfant qui va venir au monde.

VII/ V Deux espèces d’hippocampes avec une trompe ici ;
ils sont reliés les deux par quelque chose qui est là ;
ils ont l’air d’être congelés parce qu’il y a des stalactites,
comme peut-être des animaux préhistoriques qui ont été congelés.
^ Ou là sinon on peut voir des espèces de personnages
avec des bras en forme de tronçonneuse qui tentent de se rapprocher.
Des soldats de l’armée prussienne avec des pointes sur le casque.
Là on peut voir une espèce de tête avec un groin mais vu
qu’il y a une proéminence ça peut être le bouffon du roi.
Si on intègre le blanc on peut voir un masque.
V Une arme des Mayas ; ou peut-être pas une arme,
un objet Maya pour le culte
ou une espèce de champignon.

VIII/ V Une vue de microscope avec les colorants qu’il faut.
Deux espèces d’insectes qui sont en train de butiner ce qui est là.
Une tête de mouche avec quelque chose qui dégouline (orange).
Des cordes vocales (traits verts).
Un personnage avec des sortes d’antennes, en faisant
abstraction des cordes vocales.
Deux caméléons qui gravissent une montagne ;
on a l’impression qu’ils se serrent une main ;
il y a une transaction ou quelque chose comme ça :
ils donnent de l’argent ou se rechargent en énergie.

IX/ ^ Deux espèces de créatures difformes qui se rapprochent.
Deux narines, peut-être un crane qui est caché par tout le reste.
Une tête de fantôme en partie cachée par le reste
ou une sorte de champ magnétique.
Deux îles ou deux pays qui sont le reflet de l’autre (vert).
Un morceau de jambon de Parme (rose).
Des espèces de racines, comme le logo de Sépultura (traits oranges)
Une espèce de matière symbiotique qui fusionne.
Un personnage avec des ailes (vert).

X/ ^ Ca fait assez art contemporain, comme du Miro.
Deux espèces de petites bestioles qui se battent pour savoir
ce qui est au milieu (noir).
Des pieuvres ou gendarmes extraterrestres qui essayent
de les séparer (bleu).
Deux petits soleils ou comètes (jaune).
Deux chenilles ou la lettre Omega avec une araignée ou
diapason au boût (vert).
Deux sortes d’embryons qui recrachent une matière bleue (rose).
Deux espèces de fourmis avec une flamme (noir+jaune), elles sont
entrain de rattraper les deux choses qui sont là (orange)
ou la moto du Ghostrider.
V Je vois aussi deux yeux avec une bouche bizarre :
le vert c’est les cornes, le bleu la bouche, le gris un rasoir
électrique ou une sorte de tournevis sonique.
Deux personnages avec un ponpon bleu qui sont
entrain de se liquéfier, ils sont peut-être constitués de peau
et d’air (rose).
Les deux fourmis, elles vont essayer de mettre un chapeau
pour les reboucher pour pas qu’elles se dégonflent.
Deux brosses pour le dos ou à cheveux ou un compas
un peu bizarre (orange).
Finalement les deux chenilles il y a leurs projections astrales
qui est entrain de sortir de leur corps.
Deux personnes qui se soutiennent pour pas perdre l’équilibre
et pas tomber là (bleu central).

Choix + : X parce qu’on peut voir beaucoup de choses.
Choix - : II parce que ça a l’air de deux personnes qui sont entrain de se battre à mort, deux gladiateurs. Puis il y a aussi peut-être les espèces d’avions de guerre.


Rq : latences longues sauf à V et VIII
'''

# %% [markdown]
# # 1. Organizing the text into the corresponding figures and responses

# %% [markdown]
# Since the original text is in French but most of the resources are English, doing the translation after extracting the position markers may be more appropiate since the automatic translation may mess with those caracters, specially the V and mistranslate them. We are using the DeepL free API which allows for 500.000 characters a month.
#
# Another note on DeepL: there are a lot of "figures" mentioned in the target text, that is, the translation. If you look at the prompt section, the llm seems to confuse it by figures as in art figures instead of figures as in human figures. I know that when doing the DeepL API call you can pass a glossary as an argument to the function. Maybe I would be a good idea to make a glossary with more concrete terms if there are synonyms to those semantically ambiguous nouns. Alternative: look for a way to measure the specificity of a word to deal with those kinds of nouns/terms
#
# This part is commented out because there is no need to abuse the API limit, the ouput dictionary was saved as demo_text_preprocess so we can keep working on the different parts of the project.
#
# As you can see, we are doing most of the parsing with regular expressions. The flow of the function is:
# - 1st we split the text according to the roman numerals and we extract the Choix and Rq parts.
# - 2nd we clean up the response text to avoid unnecesay extralines and we extract the special markers. At this point we have two full text variables: one raw that we will extract the positional markers from and a clean copy we'll send to DeepL.
# - 3rd the clean text for each figure goes through the DeepL API and we store the translation for the whole text corresponding to the figure.
# - 4th we split the text corresponding to each figure into its individual sentences.

# %% [markdown]
# ## FX

# %%
def get_responses(raw_text):
  
  """This function takes plain text, parses the in-text markers to extract the text corresponding to each Rorschach figure,
  runs the responses through the Deepl API to translate them and returns a dictionary with the responses for each figure properly organized.
  """

  dict_numbers = {"I": 1, "II": 2,
                  "III": 3, "IV": 4,
                  "V": 5, "VI": 6,
                  "VII": 7, "VIII": 8,
                  "IX": 9, "X": 10}

  regex_response_number = '[A-Z]+/'                                # since the responses alway start with the number + \

  list_number_figure = re.findall(regex_response_number, raw_text)  # finds the regex for the number of responses

  text_i = re.split(regex_response_number, raw_text)

  # regex_choix_pos = r'Choix +(.*?)Choix -'

  # regex_choix_neg = r'Choix -(.*?)Rq :'

  # regex_rq = r'Rq :(.*?)\n'

  try: 
    
    text_choix_pos = re.findall(r'Choix \+ :(.*?)\nCh.?', raw_text)[0].strip()

    text_choix_neg = re.findall(r'Choix \- :(.*?)\n', raw_text)[0].strip()

    text_rq = re.findall(r'Rq :(.*?)\n', raw_text)[0].strip()

    additional_info = {"Choix_pos": text_choix_pos, "Choix_neg": text_choix_neg, "Rq": text_rq}
    
  except:
      
      additional_info = {"Choix_pos": "nada", "Choix_neg": "nada", "Rq": "nada"}
      
      print("Additional info not found")


  list_responses = []

  for i in range(len(list_number_figure)):

    if list_number_figure[i] not in text_i[i]:

      j = i + 1 # there is a \n\n string at index 0 so the text actually starts at index 1
      # print("not found")

    else:

      j = i

    dict_responses = {}

    n_response = list_number_figure[i][:-1]

    number = dict_numbers[n_response]

    text_i = re.split(regex_response_number, raw_text)

    full_text = text_i[j].strip()

    regex_line_break = '\n++'

    list_sentences_raw = text_i[j].split(".")

    text_i[j] = re.sub(regex_line_break, " ", text_i[j]) \
                  .replace("@", "") \
                  .replace("^", "") \
                  .replace("V", "") \
                  .replace(">", "") \
                  .replace("  ", " ") \
                  .strip() \

    # DEEPL API TRANSLATION

    with open(r"..\DEEPL_KEY\DEEPL_API_KEY.txt", "r") as f:
      API_KEY = f.read()
    
    print("API Key Found!")


    translator = deepl.Translator(API_KEY)
    result = translator.translate_text(text_i[j], target_lang="EN-US", preserve_formatting=True)

    text_i[j] = result.text

    dict_responses["figure_number"] = number

    dict_responses["raw_response"] = full_text

    dict_responses["clean_response"] = text_i[j]

    list_sentences_clean = text_i[j].split(".")

    clean_sentences = []

    i = 0

    special_markers_list = ["@", "^", "V ", "<", ">",]

    # structuring the sentences inside the while loop

    while i < len(list_sentences_clean):

      if "Choix" in list_sentences_clean[i]:  # if we reach choix, there are no more actual responses by the patient, those are just comments by the psychologist
        break

      elif "Choice" in list_sentences_clean[i]:  # if we reach choix, there are no more actual responses by the patient, those are just comments by the psychologist
        break

      j = i + 1

      # cleaning the sentences and adding the . back at the end of the sentence

      dict_sentence_info = {}

      # use the full_text of the text here to parse, the text[j is clean
      item = list_sentences_clean[i].strip()

      item_2 = list_sentences_raw[i].strip()

      if item != "":                      # split leaves an empty string at the end of the list and by adding a . , we get a "." item at the end of the list
        item = item + "."
        dict_sentence_info["response_{}".format(j)] = item
        clean_sentences.append(dict_sentence_info)


        for marker in special_markers_list:
          if marker in item_2:
            dict_sentence_info["special_marker"] = marker

      j = j + 1

      i = i + 1

    dict_responses["sentences"] = clean_sentences
        # in case we need to double-check

    list_responses.append(dict_responses)

  list_responses.append(additional_info)



  return list_responses

# %%
responses = get_responses(raw_text)
responses
# Out:
# [{'figure_number': 1,
#   'raw_response': '@ ^ Une sorte de coléoptère avec des grandes ailes\nou ça peut être une sorte de grenouille.\nV Une sorte de masque Viking avec quatre yeux.\nUne sorte de silhouette.\nUn petit personnage avec  une bouche ouverte qui a l’air surpris\net son reflet là.',
#   'clean_response': 'Some kind of beetle with big wings, or it could be some kind of frog. Some kind of iking mask with four eyes. Some kind of silhouette. A small character with an open mouth who looks surprised and his reflection there.',
#   'sentences': [{'response_1': 'Some kind of beetle with big wings, or it could be some kind of frog.',
#     'special_marker': '^'},
#    {'response_2': 'Some kind of iking mask with four eyes.',
#     'special_marker': 'V '},
#    {'response_3': 'Some kind of silhouette.'},
#    {'response_4': 'A small character with an open mouth who looks surprised and his reflection there.'}]},
#  {'figure_number': 2,
#   'raw_response': 'V Deux personnages en train d’établir un contact ou\nun combat parce qu’il y a du sang ou une jambe qui a été coupée.\nDes poumons.\n^ Une tête de coq avec la crête\nAvion de chasse, planeur, feu des réacteurs ;\nlà aussi ça peut être un plus grand qui envoie des missiles\nDes hommes troncs, peut-être irrationnels\nou des espèces de chenilles avec un gros ventre.',
#   'clean_response': "Two characters making contact or fighting because there's blood or a leg has been cut off. Lungs. A rooster's head with a crest Fighter plane, glider, jet engine fire; again, it could be a larger one sending missiles Trunk men, perhaps irrational or some kind of caterpillar with a big belly.",
#   'sentences': [{'response_1': "Two characters making contact or fighting because there's blood or a leg has been cut off.",
#     'special_marker': 'V '},
#    {'response_2': 'Lungs.'},
#    {'response_3': "A rooster's head with a crest Fighter plane, glider, jet engine fire; again, it could be a larger one sending missiles Trunk men, perhaps irrational or some kind of caterpillar with a big belly.",
#     'special_marker': '^'}]},
#  {'figure_number': 3,
#   'raw_response': '^ Deux guitares avec des formes bizarres, le manche\ntordu.\nEncore deux personnages face à face bizarrement constitués,\ncomme du Picasso. Ou deux personnages qui font qu’un.\nDeux espèces de missiles ou de torpilles.\nDes poumons\nou un papillon.\nV Juste la partie d’un vieillard avec sa canne\nou un embryon.\nUne espèce de grosse bête, on voit l’intérieur de son corps,\nLes mandibules.',
#   'clean_response': 'Two oddly shaped guitars with twisted necks. Again, two figures face to face, strangely constituted, like Picasso. Or two figures as one. Two kinds of missiles or torpedoes. Lungs or a butterfly. Just part of an old man with his cane, or an embryo. Some kind of big beast, you can see the inside of its body, the mandibles.',
#   'sentences': [{'response_1': 'Two oddly shaped guitars with twisted necks.',
#     'special_marker': '^'},
#    {'response_2': 'Again, two figures face to face, strangely constituted, like Picasso.'},
#    {'response_3': 'Or two figures as one.'},
#    {'response_4': 'Two kinds of missiles or torpedoes.'},
#    {'response_5': 'Lungs or a butterfly.'},
#    {'response_6': 'Just part of an old man with his cane, or an embryo.',
#     'special_marker': 'V '},
#    {'response_7': 'Some kind of big beast, you can see the inside of its body, the mandibles.'}]},
#  {'figure_number': 4,
#   'raw_response': 'V Je vois encore une sorte de créature bizarre, un colosse,\nAvec  les ailes là et des pattes étranges.\n^ Deux personnages sous une espèce de burka.\nV La tête de la mouche (film).\n> Tête de bébé crocodile ou de cochon vu qu’il y a pas d’oreille\nou peut-être une taupe, une sorte de trompe.',
#   'clean_response': "I see yet another bizarre creature, a colossus, with wings there and strange legs. Two figures under a kind of burka. The fly's head (film). A baby crocodile's head, or a pig's since there's no ear, or maybe a mole, some kind of trunk.",
#   'sentences': [{'response_1': 'I see yet another bizarre creature, a colossus, with wings there and strange legs.',
#     'special_marker': 'V '},
#    {'response_2': 'Two figures under a kind of burka.', 'special_marker': '^'},
#    {'response_3': "The fly's head (film).", 'special_marker': 'V '},
#    {'response_4': "A baby crocodile's head, or a pig's since there's no ear, or maybe a mole, some kind of trunk.",
#     'special_marker': '>'}]},
#  {'figure_number': 5,
#   'raw_response': '^ Je vois aussi une sorte de mélange entre une chauve-souris\net un escargot, là les pattes sont un peu étranges.\n@ Sinon là je vois rien d’autre.\nPeut-être deux têtes de personnages en tout petit,\nIls sont dos à dos.\nLe guitariste d’ACDC : sa tête avec ses cheveux.',
#   'clean_response': "I also see a sort of cross between a bat and a snail, and the legs are a bit strange. Otherwise, I don't see anything else. Maybe two very small heads, back to back. The ACDC guitarist: his head with his hair.",
#   'sentences': [{'response_1': 'I also see a sort of cross between a bat and a snail, and the legs are a bit strange.',
#     'special_marker': '^'},
#    {'response_2': "Otherwise, I don't see anything else.",
#     'special_marker': '@'},
#    {'response_3': 'Maybe two very small heads, back to back.'},
#    {'response_4': 'The ACDC guitarist: his head with his hair.'}]},
#  {'figure_number': 6,
#   'raw_response': '@ ^ Une libellule un peu bizarre avec des ailes\nà demi détruites.\nLà, la mâchoire d’une bête avec des crochets à l’intérieur\nde sa bouche, mais y a pas d’œil alors c’est peut-être\nune plante carnivore.\nL’homme sable (dans Spiderman) en train de reprendre\nforme humaine.\nSinon c’est tout ce que je vois.\nOu encore des poumons qui sont cachés juste là\nou des sortes de graines de flageolets.\nOu là une sorte de personnage avec quelque chose\npour faire des bonds.\nFinalement, c’est peut-être une sorte d’ange\nextraterrestre qui va dans une île parce qu’il y a des ailes.\nIl descend par là donc finalement c’est peut-être\nun enfant qui va venir au monde.',
#   'clean_response': "A rather bizarre dragonfly with half-destroyed wings. Here, the jaw of a beast with fangs inside its mouth, but there's no eye, so maybe it's a carnivorous plant. The Sandman (in Spiderman) returning to human form. Otherwise, that's all I can see. Or lungs hidden right there, or some kind of flageolet seeds. Or some kind of figure with something to leap on. Finally, maybe it's some kind of extraterrestrial angel going to an island because it's got wings. He comes down that way, so maybe it's a child about to be born.",
#   'sentences': [{'response_1': 'A rather bizarre dragonfly with half-destroyed wings.',
#     'special_marker': '^'},
#    {'response_2': "Here, the jaw of a beast with fangs inside its mouth, but there's no eye, so maybe it's a carnivorous plant."},
#    {'response_3': 'The Sandman (in Spiderman) returning to human form.'},
#    {'response_4': "Otherwise, that's all I can see."},
#    {'response_5': 'Or lungs hidden right there, or some kind of flageolet seeds.'},
#    {'response_6': 'Or some kind of figure with something to leap on.'},
#    {'response_7': "Finally, maybe it's some kind of extraterrestrial angel going to an island because it's got wings."},
#    {'response_8': "He comes down that way, so maybe it's a child about to be born."}]},
#  {'figure_number': 7,
#   'raw_response': 'V Deux espèces d’hippocampes avec une trompe ici ;\nils sont reliés les deux par quelque chose qui est là ;\nils ont l’air d’être congelés parce qu’il y a des stalactites,\ncomme peut-être des animaux préhistoriques qui ont été congelés.\n^ Ou là sinon on peut voir des espèces de personnages\navec des bras en forme de tronçonneuse qui tentent de se rapprocher.\nDes soldats de l’armée prussienne avec des pointes sur le casque.\nLà on peut voir une espèce de tête avec un groin mais vu\nqu’il y a une proéminence ça peut être le bouffon du roi.\nSi on intègre le blanc on peut voir un masque.\nV Une arme des Mayas ; ou peut-être pas une arme,\nun objet Maya pour le culte\nou une espèce de champignon.',
#   'clean_response': "Two species of seahorse with a proboscis here; they're both connected by something that's there; they look frozen because there are stalactites, like perhaps prehistoric animals that have been frozen. Or over there, you can see some kind of figures with chainsaw-like arms trying to get closer. Prussian army soldiers with spikes on their helmets. Here we can see a kind of head with a snout, but given the prominence, it could be the king's jester. If you integrate the white, you can see a mask. A Mayan weapon; or perhaps not a weapon, a Mayan cult object or some kind of mushroom.",
#   'sentences': [{'response_1': "Two species of seahorse with a proboscis here; they're both connected by something that's there; they look frozen because there are stalactites, like perhaps prehistoric animals that have been frozen.",
#     'special_marker': 'V '},
#    {'response_2': 'Or over there, you can see some kind of figures with chainsaw-like arms trying to get closer.',
#     'special_marker': '^'},
#    {'response_3': 'Prussian army soldiers with spikes on their helmets.'},
#    {'response_4': "Here we can see a kind of head with a snout, but given the prominence, it could be the king's jester."},
#    {'response_5': 'If you integrate the white, you can see a mask.'},
#    {'response_6': 'A Mayan weapon; or perhaps not a weapon, a Mayan cult object or some kind of mushroom.',
#     'special_marker': 'V '}]},
#  {'figure_number': 8,
#   'raw_response': 'V Une vue de microscope avec les colorants qu’il faut.\nDeux espèces d’insectes qui sont en train de butiner ce qui est là.\nUne tête de mouche avec quelque chose qui dégouline (orange).\nDes cordes vocales (traits verts).\nUn personnage avec des sortes d’antennes, en faisant\nabstraction des cordes vocales.\nDeux caméléons qui gravissent une montagne ;\non a l’impression qu’ils se serrent une main ;\nil y a une transaction ou quelque chose comme ça :\nils donnent de l’argent ou se rechargent en énergie.',
#   'clean_response': "A microscope view with the right dyes. Two species of insect foraging on what's there. A fly's head with something dripping from it (orange). Vocal cords (green lines). A character with antennae of some kind, disregarding the vocal cords. Two chameleons climbing a mountain; it looks like they're shaking hands; there's a transaction or something: they're giving money or recharging energy.",
#   'sentences': [{'response_1': 'A microscope view with the right dyes.',
#     'special_marker': 'V '},
#    {'response_2': "Two species of insect foraging on what's there."},
#    {'response_3': "A fly's head with something dripping from it (orange)."},
#    {'response_4': 'Vocal cords (green lines).'},
#    {'response_5': 'A character with antennae of some kind, disregarding the vocal cords.'},
#    {'response_6': "Two chameleons climbing a mountain; it looks like they're shaking hands; there's a transaction or something: they're giving money or recharging energy."}]},
#  {'figure_number': 9,
#   'raw_response': '^ Deux espèces de créatures difformes qui se rapprochent.\nDeux narines, peut-être un crane qui est caché par tout le reste.\nUne tête de fantôme en partie cachée par le reste\nou une sorte de champ magnétique.\nDeux îles ou deux pays qui sont le reflet de l’autre (vert).\nUn morceau de jambon de Parme (rose).\nDes espèces de racines, comme le logo de Sépultura (traits oranges)\nUne espèce de matière symbiotique qui fusionne.\nUn personnage avec des ailes (vert).',
#   'clean_response': "Two kinds of deformed creatures approaching. Two nostrils, perhaps a skull hidden by everything else. A ghost's head partly hidden by the rest, or some kind of magnetic field. Two islands or countries that reflect each other (green). A piece of Parma ham (pink). Some kind of roots, like the Sepultura logo (orange lines) Some kind of symbiotic matter that fuses together. A character with wings (green).",
#   'sentences': [{'response_1': 'Two kinds of deformed creatures approaching.',
#     'special_marker': '^'},
#    {'response_2': 'Two nostrils, perhaps a skull hidden by everything else.'},
#    {'response_3': "A ghost's head partly hidden by the rest, or some kind of magnetic field."},
#    {'response_4': 'Two islands or countries that reflect each other (green).'},
#    {'response_5': 'A piece of Parma ham (pink).'},
#    {'response_6': 'Some kind of roots, like the Sepultura logo (orange lines) Some kind of symbiotic matter that fuses together.'},
#    {'response_7': 'A character with wings (green).'}]},
#  {'figure_number': 10,
#   'raw_response': '^ Ca fait assez art contemporain, comme du Miro.\nDeux espèces de petites bestioles qui se battent pour savoir\nce qui est au milieu (noir).\nDes pieuvres ou gendarmes extraterrestres qui essayent\nde les séparer (bleu).\nDeux petits soleils ou comètes (jaune).\nDeux chenilles ou la lettre Omega avec une araignée ou\ndiapason au boût (vert).\nDeux sortes d’embryons qui recrachent une matière bleue (rose).\nDeux espèces de fourmis avec une flamme (noir+jaune), elles sont\nentrain de rattraper les deux choses qui sont là (orange)\nou la moto du Ghostrider.\nV Je vois aussi deux yeux avec une bouche bizarre :\nle vert c’est les cornes, le bleu la bouche, le gris un rasoir\nélectrique ou une sorte de tournevis sonique.\nDeux personnages avec un ponpon bleu qui sont\nentrain de se liquéfier, ils sont peut-être constitués de peau\net d’air (rose).\nLes deux fourmis, elles vont essayer de mettre un chapeau\npour les reboucher pour pas qu’elles se dégonflent.\nDeux brosses pour le dos ou à cheveux ou un compas\nun peu bizarre (orange).\nFinalement les deux chenilles il y a leurs projections astrales\nqui est entrain de sortir de leur corps.\nDeux personnes qui se soutiennent pour pas perdre l’équilibre\net pas tomber là (bleu central).\n\nChoix + : X parce qu’on peut voir beaucoup de choses.\nChoix - : II parce que ça a l’air de deux personnes qui sont entrain de se battre à mort, deux gladiateurs. Puis il y a aussi peut-être les espèces d’avions de guerre.\n\n\nRq : latences longues sauf à V et VIII',
#   'clean_response': "It's quite contemporary art, like Miro. Two species of little bugs fighting over what's in the middle (black). Octopuses or alien policemen trying to separate them (blue). Two little suns or comets (yellow). Two caterpillars or the letter Omega with a spider or tuning fork at the tip (green). Two kinds of embryos spitting out blue matter (pink). Two kinds of ants with a flame (black+yellow), catching up with the two things there (orange) or the Ghostrider's motorcycle. I also see two eyes with strange mouths: the green is the horns, the blue the mouth, the gray an electric razor or some kind of sonic screwdriver. Two figures with a blue ponpon are liquefying, perhaps made of skin and air (pink). The two ants will try to put a cap on them to stop them deflating. Two back brushes, a hairbrush or an odd compass (orange). Finally, the two caterpillars have their astral projections coming out of their bodies. Two people supporting each other so as not to lose their balance and fall (central blue). Choice + : X because you can see a lot. Choice -: II because it looks like two people fighting to the death, two gladiators. Then there are the warplanes. Rq: long latencies except at and III",
#   'sentences': [{'response_1': "It's quite contemporary art, like Miro.",
#     'special_marker': '^'},
#    {'response_2': "Two species of little bugs fighting over what's in the middle (black)."},
#    {'response_3': 'Octopuses or alien policemen trying to separate them (blue).'},
#    {'response_4': 'Two little suns or comets (yellow).'},
#    {'response_5': 'Two caterpillars or the letter Omega with a spider or tuning fork at the tip (green).'},
#    {'response_6': 'Two kinds of embryos spitting out blue matter (pink).'},
#    {'response_7': "Two kinds of ants with a flame (black+yellow), catching up with the two things there (orange) or the Ghostrider's motorcycle."},
#    {'response_8': 'I also see two eyes with strange mouths: the green is the horns, the blue the mouth, the gray an electric razor or some kind of sonic screwdriver.',
#     'special_marker': 'V '},
#    {'response_9': 'Two figures with a blue ponpon are liquefying, perhaps made of skin and air (pink).'},
#    {'response_10': 'The two ants will try to put a cap on them to stop them deflating.'},
#    {'response_11': 'Two back brushes, a hairbrush or an odd compass (orange).'},
#    {'response_12': 'Finally, the two caterpillars have their astral projections coming out of their bodies.'},
#    {'response_13': 'Two people supporting each other so as not to lose their balance and fall (central blue).'}]},
#  {'Choix_pos': 'X parce qu’on peut voir beaucoup de choses.',
#   'Choix_neg': 'II parce que ça a l’air de deux personnes qui sont entrain de se battre à mort, deux gladiateurs. Puis il y a aussi peut-être les espèces d’avions de guerre.',
#   'Rq': 'latences longues sauf à V et VIII'}]

# %%
with open(r"..\protocol example\demo_text_preprocess", "w") as f:
    json.dump(responses, f)

# %% [markdown]
# The proper clean single sentence responses in English are in the dictionary here: [{sentences: [{response_x}]}]

# %%
with open(r"..\protocol example\demo_text_preprocess", "r") as f:
    demo = json.load(f)

# %%
demo = responses
demo
# Out:
# [{'figure_number': 1,
#   'raw_response': '@ ^ Une sorte de coléoptère avec des grandes ailes\nou ça peut être une sorte de grenouille.\nV Une sorte de masque Viking avec quatre yeux.\nUne sorte de silhouette.\nUn petit personnage avec  une bouche ouverte qui a l’air surpris\net son reflet là.',
#   'clean_response': 'Some kind of beetle with big wings, or it could be some kind of frog. Some kind of iking mask with four eyes. Some kind of silhouette. A small character with an open mouth who looks surprised and his reflection there.',
#   'sentences': [{'response_1': 'Some kind of beetle with big wings, or it could be some kind of frog.',
#     'special_marker': '^'},
#    {'response_2': 'Some kind of iking mask with four eyes.',
#     'special_marker': 'V '},
#    {'response_3': 'Some kind of silhouette.'},
#    {'response_4': 'A small character with an open mouth who looks surprised and his reflection there.'}]},
#  {'figure_number': 2,
#   'raw_response': 'V Deux personnages en train d’établir un contact ou\nun combat parce qu’il y a du sang ou une jambe qui a été coupée.\nDes poumons.\n^ Une tête de coq avec la crête\nAvion de chasse, planeur, feu des réacteurs ;\nlà aussi ça peut être un plus grand qui envoie des missiles\nDes hommes troncs, peut-être irrationnels\nou des espèces de chenilles avec un gros ventre.',
#   'clean_response': "Two characters making contact or fighting because there's blood or a leg has been cut off. Lungs. A rooster's head with a crest Fighter plane, glider, jet engine fire; again, it could be a larger one sending missiles Trunk men, perhaps irrational or some kind of caterpillar with a big belly.",
#   'sentences': [{'response_1': "Two characters making contact or fighting because there's blood or a leg has been cut off.",
#     'special_marker': 'V '},
#    {'response_2': 'Lungs.'},
#    {'response_3': "A rooster's head with a crest Fighter plane, glider, jet engine fire; again, it could be a larger one sending missiles Trunk men, perhaps irrational or some kind of caterpillar with a big belly.",
#     'special_marker': '^'}]},
#  {'figure_number': 3,
#   'raw_response': '^ Deux guitares avec des formes bizarres, le manche\ntordu.\nEncore deux personnages face à face bizarrement constitués,\ncomme du Picasso. Ou deux personnages qui font qu’un.\nDeux espèces de missiles ou de torpilles.\nDes poumons\nou un papillon.\nV Juste la partie d’un vieillard avec sa canne\nou un embryon.\nUne espèce de grosse bête, on voit l’intérieur de son corps,\nLes mandibules.',
#   'clean_response': 'Two oddly shaped guitars with twisted necks. Again, two figures face to face, strangely constituted, like Picasso. Or two figures as one. Two kinds of missiles or torpedoes. Lungs or a butterfly. Just part of an old man with his cane, or an embryo. Some kind of big beast, you can see the inside of its body, the mandibles.',
#   'sentences': [{'response_1': 'Two oddly shaped guitars with twisted necks.',
#     'special_marker': '^'},
#    {'response_2': 'Again, two figures face to face, strangely constituted, like Picasso.'},
#    {'response_3': 'Or two figures as one.'},
#    {'response_4': 'Two kinds of missiles or torpedoes.'},
#    {'response_5': 'Lungs or a butterfly.'},
#    {'response_6': 'Just part of an old man with his cane, or an embryo.',
#     'special_marker': 'V '},
#    {'response_7': 'Some kind of big beast, you can see the inside of its body, the mandibles.'}]},
#  {'figure_number': 4,
#   'raw_response': 'V Je vois encore une sorte de créature bizarre, un colosse,\nAvec  les ailes là et des pattes étranges.\n^ Deux personnages sous une espèce de burka.\nV La tête de la mouche (film).\n> Tête de bébé crocodile ou de cochon vu qu’il y a pas d’oreille\nou peut-être une taupe, une sorte de trompe.',
#   'clean_response': "I see yet another bizarre creature, a colossus, with wings there and strange legs. Two figures under a kind of burka. The fly's head (film). A baby crocodile's head, or a pig's since there's no ear, or maybe a mole, some kind of trunk.",
#   'sentences': [{'response_1': 'I see yet another bizarre creature, a colossus, with wings there and strange legs.',
#     'special_marker': 'V '},
#    {'response_2': 'Two figures under a kind of burka.', 'special_marker': '^'},
#    {'response_3': "The fly's head (film).", 'special_marker': 'V '},
#    {'response_4': "A baby crocodile's head, or a pig's since there's no ear, or maybe a mole, some kind of trunk.",
#     'special_marker': '>'}]},
#  {'figure_number': 5,
#   'raw_response': '^ Je vois aussi une sorte de mélange entre une chauve-souris\net un escargot, là les pattes sont un peu étranges.\n@ Sinon là je vois rien d’autre.\nPeut-être deux têtes de personnages en tout petit,\nIls sont dos à dos.\nLe guitariste d’ACDC : sa tête avec ses cheveux.',
#   'clean_response': "I also see a sort of cross between a bat and a snail, and the legs are a bit strange. Otherwise, I don't see anything else. Maybe two very small heads, back to back. The ACDC guitarist: his head with his hair.",
#   'sentences': [{'response_1': 'I also see a sort of cross between a bat and a snail, and the legs are a bit strange.',
#     'special_marker': '^'},
#    {'response_2': "Otherwise, I don't see anything else.",
#     'special_marker': '@'},
#    {'response_3': 'Maybe two very small heads, back to back.'},
#    {'response_4': 'The ACDC guitarist: his head with his hair.'}]},
#  {'figure_number': 6,
#   'raw_response': '@ ^ Une libellule un peu bizarre avec des ailes\nà demi détruites.\nLà, la mâchoire d’une bête avec des crochets à l’intérieur\nde sa bouche, mais y a pas d’œil alors c’est peut-être\nune plante carnivore.\nL’homme sable (dans Spiderman) en train de reprendre\nforme humaine.\nSinon c’est tout ce que je vois.\nOu encore des poumons qui sont cachés juste là\nou des sortes de graines de flageolets.\nOu là une sorte de personnage avec quelque chose\npour faire des bonds.\nFinalement, c’est peut-être une sorte d’ange\nextraterrestre qui va dans une île parce qu’il y a des ailes.\nIl descend par là donc finalement c’est peut-être\nun enfant qui va venir au monde.',
#   'clean_response': "A rather bizarre dragonfly with half-destroyed wings. Here, the jaw of a beast with fangs inside its mouth, but there's no eye, so maybe it's a carnivorous plant. The Sandman (in Spiderman) returning to human form. Otherwise, that's all I can see. Or lungs hidden right there, or some kind of flageolet seeds. Or some kind of figure with something to leap on. Finally, maybe it's some kind of extraterrestrial angel going to an island because it's got wings. He comes down that way, so maybe it's a child about to be born.",
#   'sentences': [{'response_1': 'A rather bizarre dragonfly with half-destroyed wings.',
#     'special_marker': '^'},
#    {'response_2': "Here, the jaw of a beast with fangs inside its mouth, but there's no eye, so maybe it's a carnivorous plant."},
#    {'response_3': 'The Sandman (in Spiderman) returning to human form.'},
#    {'response_4': "Otherwise, that's all I can see."},
#    {'response_5': 'Or lungs hidden right there, or some kind of flageolet seeds.'},
#    {'response_6': 'Or some kind of figure with something to leap on.'},
#    {'response_7': "Finally, maybe it's some kind of extraterrestrial angel going to an island because it's got wings."},
#    {'response_8': "He comes down that way, so maybe it's a child about to be born."}]},
#  {'figure_number': 7,
#   'raw_response': 'V Deux espèces d’hippocampes avec une trompe ici ;\nils sont reliés les deux par quelque chose qui est là ;\nils ont l’air d’être congelés parce qu’il y a des stalactites,\ncomme peut-être des animaux préhistoriques qui ont été congelés.\n^ Ou là sinon on peut voir des espèces de personnages\navec des bras en forme de tronçonneuse qui tentent de se rapprocher.\nDes soldats de l’armée prussienne avec des pointes sur le casque.\nLà on peut voir une espèce de tête avec un groin mais vu\nqu’il y a une proéminence ça peut être le bouffon du roi.\nSi on intègre le blanc on peut voir un masque.\nV Une arme des Mayas ; ou peut-être pas une arme,\nun objet Maya pour le culte\nou une espèce de champignon.',
#   'clean_response': "Two species of seahorse with a proboscis here; they're both connected by something that's there; they look frozen because there are stalactites, like perhaps prehistoric animals that have been frozen. Or over there, you can see some kind of figures with chainsaw-like arms trying to get closer. Prussian army soldiers with spikes on their helmets. Here we can see a kind of head with a snout, but given the prominence, it could be the king's jester. If you integrate the white, you can see a mask. A Mayan weapon; or perhaps not a weapon, a Mayan cult object or some kind of mushroom.",
#   'sentences': [{'response_1': "Two species of seahorse with a proboscis here; they're both connected by something that's there; they look frozen because there are stalactites, like perhaps prehistoric animals that have been frozen.",
#     'special_marker': 'V '},
#    {'response_2': 'Or over there, you can see some kind of figures with chainsaw-like arms trying to get closer.',
#     'special_marker': '^'},
#    {'response_3': 'Prussian army soldiers with spikes on their helmets.'},
#    {'response_4': "Here we can see a kind of head with a snout, but given the prominence, it could be the king's jester."},
#    {'response_5': 'If you integrate the white, you can see a mask.'},
#    {'response_6': 'A Mayan weapon; or perhaps not a weapon, a Mayan cult object or some kind of mushroom.',
#     'special_marker': 'V '}]},
#  {'figure_number': 8,
#   'raw_response': 'V Une vue de microscope avec les colorants qu’il faut.\nDeux espèces d’insectes qui sont en train de butiner ce qui est là.\nUne tête de mouche avec quelque chose qui dégouline (orange).\nDes cordes vocales (traits verts).\nUn personnage avec des sortes d’antennes, en faisant\nabstraction des cordes vocales.\nDeux caméléons qui gravissent une montagne ;\non a l’impression qu’ils se serrent une main ;\nil y a une transaction ou quelque chose comme ça :\nils donnent de l’argent ou se rechargent en énergie.',
#   'clean_response': "A microscope view with the right dyes. Two species of insect foraging on what's there. A fly's head with something dripping from it (orange). Vocal cords (green lines). A character with antennae of some kind, disregarding the vocal cords. Two chameleons climbing a mountain; it looks like they're shaking hands; there's a transaction or something: they're giving money or recharging energy.",
#   'sentences': [{'response_1': 'A microscope view with the right dyes.',
#     'special_marker': 'V '},
#    {'response_2': "Two species of insect foraging on what's there."},
#    {'response_3': "A fly's head with something dripping from it (orange)."},
#    {'response_4': 'Vocal cords (green lines).'},
#    {'response_5': 'A character with antennae of some kind, disregarding the vocal cords.'},
#    {'response_6': "Two chameleons climbing a mountain; it looks like they're shaking hands; there's a transaction or something: they're giving money or recharging energy."}]},
#  {'figure_number': 9,
#   'raw_response': '^ Deux espèces de créatures difformes qui se rapprochent.\nDeux narines, peut-être un crane qui est caché par tout le reste.\nUne tête de fantôme en partie cachée par le reste\nou une sorte de champ magnétique.\nDeux îles ou deux pays qui sont le reflet de l’autre (vert).\nUn morceau de jambon de Parme (rose).\nDes espèces de racines, comme le logo de Sépultura (traits oranges)\nUne espèce de matière symbiotique qui fusionne.\nUn personnage avec des ailes (vert).',
#   'clean_response': "Two kinds of deformed creatures approaching. Two nostrils, perhaps a skull hidden by everything else. A ghost's head partly hidden by the rest, or some kind of magnetic field. Two islands or countries that reflect each other (green). A piece of Parma ham (pink). Some kind of roots, like the Sepultura logo (orange lines) Some kind of symbiotic matter that fuses together. A character with wings (green).",
#   'sentences': [{'response_1': 'Two kinds of deformed creatures approaching.',
#     'special_marker': '^'},
#    {'response_2': 'Two nostrils, perhaps a skull hidden by everything else.'},
#    {'response_3': "A ghost's head partly hidden by the rest, or some kind of magnetic field."},
#    {'response_4': 'Two islands or countries that reflect each other (green).'},
#    {'response_5': 'A piece of Parma ham (pink).'},
#    {'response_6': 'Some kind of roots, like the Sepultura logo (orange lines) Some kind of symbiotic matter that fuses together.'},
#    {'response_7': 'A character with wings (green).'}]},
#  {'figure_number': 10,
#   'raw_response': '^ Ca fait assez art contemporain, comme du Miro.\nDeux espèces de petites bestioles qui se battent pour savoir\nce qui est au milieu (noir).\nDes pieuvres ou gendarmes extraterrestres qui essayent\nde les séparer (bleu).\nDeux petits soleils ou comètes (jaune).\nDeux chenilles ou la lettre Omega avec une araignée ou\ndiapason au boût (vert).\nDeux sortes d’embryons qui recrachent une matière bleue (rose).\nDeux espèces de fourmis avec une flamme (noir+jaune), elles sont\nentrain de rattraper les deux choses qui sont là (orange)\nou la moto du Ghostrider.\nV Je vois aussi deux yeux avec une bouche bizarre :\nle vert c’est les cornes, le bleu la bouche, le gris un rasoir\nélectrique ou une sorte de tournevis sonique.\nDeux personnages avec un ponpon bleu qui sont\nentrain de se liquéfier, ils sont peut-être constitués de peau\net d’air (rose).\nLes deux fourmis, elles vont essayer de mettre un chapeau\npour les reboucher pour pas qu’elles se dégonflent.\nDeux brosses pour le dos ou à cheveux ou un compas\nun peu bizarre (orange).\nFinalement les deux chenilles il y a leurs projections astrales\nqui est entrain de sortir de leur corps.\nDeux personnes qui se soutiennent pour pas perdre l’équilibre\net pas tomber là (bleu central).\n\nChoix + : X parce qu’on peut voir beaucoup de choses.\nChoix - : II parce que ça a l’air de deux personnes qui sont entrain de se battre à mort, deux gladiateurs. Puis il y a aussi peut-être les espèces d’avions de guerre.\n\n\nRq : latences longues sauf à V et VIII',
#   'clean_response': "It's quite contemporary art, like Miro. Two species of little bugs fighting over what's in the middle (black). Octopuses or alien policemen trying to separate them (blue). Two little suns or comets (yellow). Two caterpillars or the letter Omega with a spider or tuning fork at the tip (green). Two kinds of embryos spitting out blue matter (pink). Two kinds of ants with a flame (black+yellow), catching up with the two things there (orange) or the Ghostrider's motorcycle. I also see two eyes with strange mouths: the green is the horns, the blue the mouth, the gray an electric razor or some kind of sonic screwdriver. Two figures with a blue ponpon are liquefying, perhaps made of skin and air (pink). The two ants will try to put a cap on them to stop them deflating. Two back brushes, a hairbrush or an odd compass (orange). Finally, the two caterpillars have their astral projections coming out of their bodies. Two people supporting each other so as not to lose their balance and fall (central blue). Choice + : X because you can see a lot. Choice -: II because it looks like two people fighting to the death, two gladiators. Then there are the warplanes. Rq: long latencies except at and III",
#   'sentences': [{'response_1': "It's quite contemporary art, like Miro.",
#     'special_marker': '^'},
#    {'response_2': "Two species of little bugs fighting over what's in the middle (black)."},
#    {'response_3': 'Octopuses or alien policemen trying to separate them (blue).'},
#    {'response_4': 'Two little suns or comets (yellow).'},
#    {'response_5': 'Two caterpillars or the letter Omega with a spider or tuning fork at the tip (green).'},
#    {'response_6': 'Two kinds of embryos spitting out blue matter (pink).'},
#    {'response_7': "Two kinds of ants with a flame (black+yellow), catching up with the two things there (orange) or the Ghostrider's motorcycle."},
#    {'response_8': 'I also see two eyes with strange mouths: the green is the horns, the blue the mouth, the gray an electric razor or some kind of sonic screwdriver.',
#     'special_marker': 'V '},
#    {'response_9': 'Two figures with a blue ponpon are liquefying, perhaps made of skin and air (pink).'},
#    {'response_10': 'The two ants will try to put a cap on them to stop them deflating.'},
#    {'response_11': 'Two back brushes, a hairbrush or an odd compass (orange).'},
#    {'response_12': 'Finally, the two caterpillars have their astral projections coming out of their bodies.'},
#    {'response_13': 'Two people supporting each other so as not to lose their balance and fall (central blue).'}]},
#  {'Choix_pos': 'X parce qu’on peut voir beaucoup de choses.',
#   'Choix_neg': 'II parce que ça a l’air de deux personnes qui sont entrain de se battre à mort, deux gladiateurs. Puis il y a aussi peut-être les espèces d’avions de guerre.',
#   'Rq': 'latences longues sauf à V et VIII'}]

# %% [markdown]
# # 2 Filtering the responses from the dictionary
#
# This next couple of functions just take the previous dictionary and extracts just the sentences. It "shaves off" all the unnecesary fluff which will not be useful to process the text.

# %% [markdown]
# ## FX

# %%
def get_list_figure_responses(og_dict):

    responses_list = []

    for figure in og_dict[:-1]:

        figure_sents = figure["sentences"]

        for item in figure_sents:

            item.pop("special_marker", None)
        responses_list.append(figure_sents)

    return responses_list

def clean_dict(responses_fig_list):

    '''merges the dictionary for each the responses of a figure into one response
    to go from a list of dicts [{response: blablabla},  {response: blablabla}, {response: blablabla}]
    to just one dict{response_1: , response_2: , response_3: }

    '''

    new_dict = {}
    for dictionary in responses_fig_list:
            for k , v in dictionary.items():
                # print(k,v)
                new_dict[k]= v
    return new_dict

# def figure_df(clean_dict):
#     '''gets the previous clean dict and turns it into a dataframe
#     '''
#     clean_responses_df = pd.DataFrame.from_dict(clean_dict, orient='index')
#     return clean_responses_df

# %%
def transform_dictionary_to_figure_list(og_dictionary):
    '''this function transforms the first dictionary
    into individual response dictionaries for each figure and returns it in list form.
    '''

    responses_list = get_list_figure_responses(og_dictionary)

    clean_fig_1 = clean_dict(responses_list[0])
    clean_fig_2 = clean_dict(responses_list[1])
    clean_fig_3 = clean_dict(responses_list[2])
    clean_fig_4 = clean_dict(responses_list[3])
    clean_fig_5 = clean_dict(responses_list[4])
    clean_fig_6 = clean_dict(responses_list[5])
    clean_fig_7 = clean_dict(responses_list[6])
    clean_fig_8 = clean_dict(responses_list[7])
    clean_fig_9 = clean_dict(responses_list[8])
    clean_fig_10 = clean_dict(responses_list[9])

    list_dicts = [clean_fig_1, clean_fig_2, clean_fig_3, clean_fig_4, clean_fig_5, clean_fig_6, clean_fig_7, clean_fig_8, clean_fig_9, clean_fig_10]

    return list_dicts

# %% [markdown]
# The output of the functions look something like this:

# %%
with open(r"..\protocol example\list_responses_clean.json", "r") as f:
    list_dicts = json.load(f)

# %%
list_dicts
# Out:
# [{'response_1': 'Some kind of beetle with big wings, or it could be some kind of frog.',
#   'response_2': 'Some kind of iking mask with four eyes.',
#   'response_3': 'Some kind of silhouette.',
#   'response_4': 'A small character with an open mouth who looks surprised and his reflection there.'},
#  {'response_1': "Two characters making contact or fighting because there's blood or a leg has been cut off.",
#   'response_2': 'Lungs.',
#   'response_3': "A rooster's head with a crest Fighter plane, glider, jet engine fire; again, it could be a larger one sending missiles Trunk men, perhaps irrational or some kind of caterpillar with a big belly."},
#  {'response_1': 'Two oddly shaped guitars with twisted necks.',
#   'response_2': 'Again, two figures face to face, strangely constituted, like Picasso.',
#   'response_3': 'Or two figures as one.',
#   'response_4': 'Two kinds of missiles or torpedoes.',
#   'response_5': 'Lungs or a butterfly.',
#   'response_6': 'Just part of an old man with his cane, or an embryo.',
#   'response_7': 'Some kind of big beast, you can see the inside of its body, the mandibles.'},
#  {'response_1': 'I see yet another bizarre creature, a colossus, with wings there and strange legs.',
#   'response_2': 'Two figures under a kind of burka.',
#   'response_3': "The fly's head (film).",
#   'response_4': "A baby crocodile's head, or a pig's since there's no ear, or maybe a mole, some kind of trunk."},
#  {'response_1': 'I also see a sort of cross between a bat and a snail, and the legs are a bit strange.',
#   'response_2': "Otherwise, I don't see anything else.",
#   'response_3': 'Maybe two very small heads, back to back.',
#   'response_4': 'The ACDC guitarist: his head with his hair.'},
#  {'response_1': 'A rather bizarre dragonfly with half-destroyed wings.',
#   'response_2': "Here, the jaw of a beast with fangs inside its mouth, but there's no eye, so maybe it's a carnivorous plant.",
#   'response_3': 'The Sandman (in Spiderman) returning to human form.',
#   'response_4': "Otherwise, that's all I can see.",
#   'response_5': 'Or lungs hidden right there, or some kind of flageolet seeds.',
#   'response_6': 'Or some kind of figure with something to leap on.',
#   'response_7': "Finally, maybe it's some kind of extraterrestrial angel going to an island because it's got wings.",
#   'response_8': "He comes down that way, so maybe it's a child about to be born."},
#  {'response_1': "Two species of seahorse with a proboscis here; they're both connected by something that's there; they look frozen because there are stalactites, like perhaps prehistoric animals that have been frozen.",
#   'response_2': 'Or over there, you can see some kind of figures with chainsaw-like arms trying to get closer.',
#   'response_3': 'Prussian army soldiers with spikes on their helmets.',
#   'response_4': "Here we can see a kind of head with a snout, but given the prominence, it could be the king's jester.",
#   'response_5': 'If you integrate the white, you can see a mask.',
#   'response_6': 'A Mayan weapon; or perhaps not a weapon, a Mayan cult object or some kind of mushroom.'},
#  {'response_1': 'A microscope view with the right dyes.',
#   'response_2': "Two species of insect foraging on what's there.",
#   'response_3': "A fly's head with something dripping from it (orange).",
#   'response_4': 'Vocal cords (green lines).',
#   'response_5': 'A character with antennae of some kind, disregarding the vocal cords.',
#   'response_6': "Two chameleons climbing a mountain; it looks like they're shaking hands; there's a transaction or something: they're giving money or recharging energy."},
#  {'response_1': 'Two kinds of deformed creatures approaching.',
#   'response_2': 'Two nostrils, perhaps a skull hidden by everything else.',
#   'response_3': "A ghost's head partly hidden by the rest, or some kind of magnetic field.",
#   'response_4': 'Two islands or countries that reflect each other (green).',
#   'response_5': 'A piece of Parma ham (pink).',
#   'response_6': 'Some kind of roots, like the Sepultura logo (orange lines) Some kind of symbiotic matter that fuses together.',
#   'response_7': 'A character with wings (green).'},
#  {'response_1': "It's quite contemporary art, like Miro.",
#   'response_2': "Two species of little bugs fighting over what's in the middle (black).",
#   'response_3': 'Octopuses or alien policemen trying to separate them (blue).',
#   'response_4': 'Two little suns or comets (yellow).',
#   'response_5': 'Two caterpillars or the letter Omega with a spider or tuning fork at the tip (green).',
#   'response_6': 'Two kinds of embryos spitting out blue matter (pink).',
#   'response_7': "Two kinds of ants with a flame (black+yellow), catching up with the two things there (orange) or the Ghostrider's motorcycle.",
#   'response_8': 'I also see two eyes with strange mouths: the green is the horns, the blue the mouth, the gray an electric razor or some kind of sonic screwdriver.',
#   'response_9': 'Two figures with a blue ponpon are liquefying, perhaps made of skin and air (pink).',
#   'response_10': 'The two ants will try to put a cap on them to stop them deflating.',
#   'response_11': 'Two back brushes, a hairbrush or an odd compass (orange).',
#   'response_12': 'Finally, the two caterpillars have their astral projections coming out of their bodies.',
#   'response_13': 'Two people supporting each other so as not to lose their balance and fall (central blue).'}]

# %%
list_dicts = transform_dictionary_to_figure_list(demo)
list_dicts
# Out:
# [{'response_1': 'Some kind of beetle with big wings, or it could be some kind of frog.',
#   'response_2': 'Some kind of iking mask with four eyes.',
#   'response_3': 'Some kind of silhouette.',
#   'response_4': 'A small character with an open mouth who looks surprised and his reflection there.'},
#  {'response_1': "Two characters making contact or fighting because there's blood or a leg has been cut off.",
#   'response_2': 'Lungs.',
#   'response_3': "A rooster's head with a crest Fighter plane, glider, jet engine fire; again, it could be a larger one sending missiles Trunk men, perhaps irrational or some kind of caterpillar with a big belly."},
#  {'response_1': 'Two oddly shaped guitars with twisted necks.',
#   'response_2': 'Again, two figures face to face, strangely constituted, like Picasso.',
#   'response_3': 'Or two figures as one.',
#   'response_4': 'Two kinds of missiles or torpedoes.',
#   'response_5': 'Lungs or a butterfly.',
#   'response_6': 'Just part of an old man with his cane, or an embryo.',
#   'response_7': 'Some kind of big beast, you can see the inside of its body, the mandibles.'},
#  {'response_1': 'I see yet another bizarre creature, a colossus, with wings there and strange legs.',
#   'response_2': 'Two figures under a kind of burka.',
#   'response_3': "The fly's head (film).",
#   'response_4': "A baby crocodile's head, or a pig's since there's no ear, or maybe a mole, some kind of trunk."},
#  {'response_1': 'I also see a sort of cross between a bat and a snail, and the legs are a bit strange.',
#   'response_2': "Otherwise, I don't see anything else.",
#   'response_3': 'Maybe two very small heads, back to back.',
#   'response_4': 'The ACDC guitarist: his head with his hair.'},
#  {'response_1': 'A rather bizarre dragonfly with half-destroyed wings.',
#   'response_2': "Here, the jaw of a beast with fangs inside its mouth, but there's no eye, so maybe it's a carnivorous plant.",
#   'response_3': 'The Sandman (in Spiderman) returning to human form.',
#   'response_4': "Otherwise, that's all I can see.",
#   'response_5': 'Or lungs hidden right there, or some kind of flageolet seeds.',
#   'response_6': 'Or some kind of figure with something to leap on.',
#   'response_7': "Finally, maybe it's some kind of extraterrestrial angel going to an island because it's got wings.",
#   'response_8': "He comes down that way, so maybe it's a child about to be born."},
#  {'response_1': "Two species of seahorse with a proboscis here; they're both connected by something that's there; they look frozen because there are stalactites, like perhaps prehistoric animals that have been frozen.",
#   'response_2': 'Or over there, you can see some kind of figures with chainsaw-like arms trying to get closer.',
#   'response_3': 'Prussian army soldiers with spikes on their helmets.',
#   'response_4': "Here we can see a kind of head with a snout, but given the prominence, it could be the king's jester.",
#   'response_5': 'If you integrate the white, you can see a mask.',
#   'response_6': 'A Mayan weapon; or perhaps not a weapon, a Mayan cult object or some kind of mushroom.'},
#  {'response_1': 'A microscope view with the right dyes.',
#   'response_2': "Two species of insect foraging on what's there.",
#   'response_3': "A fly's head with something dripping from it (orange).",
#   'response_4': 'Vocal cords (green lines).',
#   'response_5': 'A character with antennae of some kind, disregarding the vocal cords.',
#   'response_6': "Two chameleons climbing a mountain; it looks like they're shaking hands; there's a transaction or something: they're giving money or recharging energy."},
#  {'response_1': 'Two kinds of deformed creatures approaching.',
#   'response_2': 'Two nostrils, perhaps a skull hidden by everything else.',
#   'response_3': "A ghost's head partly hidden by the rest, or some kind of magnetic field.",
#   'response_4': 'Two islands or countries that reflect each other (green).',
#   'response_5': 'A piece of Parma ham (pink).',
#   'response_6': 'Some kind of roots, like the Sepultura logo (orange lines) Some kind of symbiotic matter that fuses together.',
#   'response_7': 'A character with wings (green).'},
#  {'response_1': "It's quite contemporary art, like Miro.",
#   'response_2': "Two species of little bugs fighting over what's in the middle (black).",
#   'response_3': 'Octopuses or alien policemen trying to separate them (blue).',
#   'response_4': 'Two little suns or comets (yellow).',
#   'response_5': 'Two caterpillars or the letter Omega with a spider or tuning fork at the tip (green).',
#   'response_6': 'Two kinds of embryos spitting out blue matter (pink).',
#   'response_7': "Two kinds of ants with a flame (black+yellow), catching up with the two things there (orange) or the Ghostrider's motorcycle.",
#   'response_8': 'I also see two eyes with strange mouths: the green is the horns, the blue the mouth, the gray an electric razor or some kind of sonic screwdriver.',
#   'response_9': 'Two figures with a blue ponpon are liquefying, perhaps made of skin and air (pink).',
#   'response_10': 'The two ants will try to put a cap on them to stop them deflating.',
#   'response_11': 'Two back brushes, a hairbrush or an odd compass (orange).',
#   'response_12': 'Finally, the two caterpillars have their astral projections coming out of their bodies.',
#   'response_13': 'Two people supporting each other so as not to lose their balance and fall (central blue).'}]

# %%
with open(r"..\protocol example\list_responses_clean.json", "w") as f:
    json.dump(list_dicts, f)

# %% [markdown]
# # Clean Noun Phrases (in progress, experimentation in Getting_noun_phrases.ipynb)
#
# To mirror the input of the training data that will be use to train the model, instead of using the whole sentence, the noun phrases corresponding to each response will be extracted so that it can be fed to the model as the input to classify. Moreover, since there are many responses which actually contain more than one response, that is, several responses are coordinated with conjunctions, that will also be dealt with in this step.

# %%
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## FX

# %%
def get_noun_phrase(doc):
    """Takes a NLP spaCy doc as an input and outputs the noun phrase subtree at the highest depth within the syntax tree
    """
    # print(doc)
    list_dependencies = ["nsubj", "pobj", "attr", "agent", "csubj", "csubjpass", "npmod", "oprd", "pobj", "dative", "appos", "ROOT"]
    pos = ["NOUN", "PROPN", "NUM"]
    
    trans_dictionary = {"[": "", 
                    "]": "", 
                    ",": "",
                    ".": "",
                    "  ": "",
                    " '": "'",
                    ".":",",
                    " )": ")",
                    "( ": "("}
    
    for token in doc:
        # print(token)


        if token.dep_ in list_dependencies and token.pos_ in pos and token.pos_ != "PRON":  # remove personal pronouns?
            ancestors = [t for t in token.ancestors if t.dep_ in list_dependencies and t.pos_ != "PRON" and t.dep_ !="ROOT"]
            
            # in the above code, verify that the "ROOT" dependency acts the way we intend
            
            # print(token,"ancestors:", ancestors)
            
            len_ancestors = len(ancestors)
            # print(ancestors, len_ancestors)
            if len_ancestors > 0 :
                continue
                
            elif len_ancestors == 0 :
                
                og_ancestor = token

                final_children = [t for t in og_ancestor.children]
                
                for child in final_children:
                    grand_children = [t for t in child.children] # this way we get all the tree under the og ancestor
                    for item in grand_children:
                        if item != None:
                            final_children.append(item)
                            
                final_children = final_children + [og_ancestor]  
                
                sorted_sentence = sorted(final_children) # if needed, we can access the token's index with token.i
                response = str(sorted_sentence).replace("[", "").replace("]", "").replace(",", "").replace("  ", " ").replace(".", "").replace(" )", ")").replace("( ", "(").strip(" ") #to clean the response
                # print(response)
                return response
                # sometimes the response will be empty
    return "no meaningful NP found"

# %%
# def get_clean_NP_responses(list_of_dictionary_responses):
#     """Takes a dictionary with responses as input 
#     and outputs a dictionary with the noun phrases from those responses
#     """
#     clean_np_list = []
    
#     for dictionary_response in list_of_dictionary_responses:
            
#         clean_np_responses = {}

#         for key, sentence in list(dictionary_response.items()):
            
#             response_dict = {}
             
#             # i will be using this to reintroduce sliced sentences into the dictionary at the end
#             list_keys = list(dictionary_response.keys())
#             last_key = list_keys[-1]
#             key_template = str(last_key[:-1])+"{}"
#             last_number = last_key[-1]

#             doc = nlp(sentence)
            
#             coordination = [(token, token.dep_, token.i) for token in doc if token.dep_ == "cc"] 
            
#             if len(coordination) > 0 :  # slice the sentence by a token and add another response to the list
                
#                 # print(coordination)
#                 list_indexes = []
                
#                 for tuple in coordination:  # if there are more than one instances of coordination we'll need access to the indexes of every cc to know where to cut the sentences
#                     index_cut = tuple[2]
#                     list_indexes.append(index_cut)
                    
#                 new_sentences = []
                
#                 for i in range(len(list_indexes)):
                    
#                     first_new_sentence = doc[:list_indexes[i]].text
#                     try:
#                         second_new_sentence = doc[list_indexes[i]+1:list_indexes[i+1]].text # will execute if there are more than one "cc"s
#                     except:
#                         second_new_sentence = doc[list_indexes[i]+1:].text
                    
#                     new_sentences.append(first_new_sentence)
#                     new_sentences.append(second_new_sentence)
                
#                 del dictionary_response[key]
#                 list_keys = list(dictionary_response.keys())
#                 last_key = list_keys[-1]
#                 key_template = str(last_key[:-1])+"{}"
#                 last_number = last_key[-1]
                
#                 for i in range(len(new_sentences)):
#                     new_index_key = int(last_number) + i + 1 # since i will be 0 we have to add one so that we don't overwrite the last key
#                     new_key = key_template.format(new_index_key)
            
#                     doc = nlp(new_sentences[i])
#                     # print(doc)
#                     response_chopped_sentence = get_noun_phrase(doc)
#                     np_key = len(list(clean_np_responses.keys())) + 1
#                     clean_np_responses["response_{}".format(np_key)] = response_chopped_sentence
#                     # response_dict[sentence] = response_chopped_sentence
                    
#             elif len(coordination) == 0:
#                 # print(doc)
#                 response = get_noun_phrase(doc)
#                 np_key = len(list(clean_np_responses.keys())) + 1
#                 clean_np_responses["response_{}".format(np_key)] = response
#                 # response_dict[sentence] = response_chopped_sentence
                
#         clean_np_list.append(clean_np_responses)
        
#     return clean_np_list

# %% [markdown]
# Adapting the function for individual responses

# %%
def get_np(sentence):
    
    doc = nlp(sentence)

    coordination = [(token, token.dep_, token.i) for token in doc if token.dep_ == "cc"]
    
    if len(coordination) > 0 :  # slice the sentence by a token and add another response to the list
        
        # print(coordination)
        list_indexes = []
        
        for tuple in coordination:  # if there are more than one instances of coordination we'll need access to the indexes of every cc to know where to cut the sentences
            index_cut = tuple[2]
            list_indexes.append(index_cut)
            
        new_sentences = []
        
        for i in range(len(list_indexes)):
            
            first_new_sentence = doc[:list_indexes[i]].text
            try:
                second_new_sentence = doc[list_indexes[i]+1:list_indexes[i+1]].text # will execute if there are more than one "cc"s
            except:
                second_new_sentence = doc[list_indexes[i]+1:].text
            
            new_sentences.append(first_new_sentence)
            new_sentences.append(second_new_sentence)
            
        # print(new_sentences)
        
        for i in range(len(new_sentences)):

            doc = nlp(new_sentences[i])
            # print(doc)
            response_chopped_sentence = get_noun_phrase(doc)
            
            # print(response_chopped_sentence)
            
            new_sentences[i] = response_chopped_sentence
        
        coordination = True
        # print(new_sentences)
        return new_sentences, coordination

    elif len(coordination) == 0:
        # print(doc)
        response = get_noun_phrase(doc)
        
        coordination = False
        
        return response, coordination

# %%
# clean_np_responses = get_clean_NP_responses(list_dicts)
# clean_np_responses

# %%
for dic in list_dicts:
    for key, sentence in dic.items():
        print(get_np(sentence))
# Out:
# (['Some kind of beetle with big wings', 'some kind of frog'], True)
# ('Some kind of iking mask with four eyes', False)
# ('Some kind of silhouette', False)
# (['A small character with an open mouth who looks surprised', 'his reflection there'], True)
# (['Two characters', 'blood', "Two characters making contact or fighting because there 's blood", 'no meaningful NP found'], True)
# ('Lungs', False)
# (["A rooster 's head with a crest Fighter plane glider jet engine fire", 'some kind of caterpillar with a big belly'], True)
# ('Two', False)
# ('two figures', False)
# (['no meaningful NP found', 'two figures as one'], True)
# (['Two kinds of missiles', 'no meaningful NP found'], True)
# (['Lungs', 'a butterfly'], True)
# (['Just part of an old man with his cane', 'an embryo'], True)
# ('big beast', False)
# (['a colossus', 'strange legs'], True)
# ('Two figures under a kind of burka', False)
# ("The fly 's head (film)", False)
# (["A baby crocodile 's head", "a pig 's since there 's no ear", "A baby crocodile 's head or a pig 's since there 's no ear", 'maybe a mole some kind of trunk'], True)
# (['cross', 'a snail', 'cross', 'the legs'], True)
# ('no meaningful NP found', False)
# ('Maybe two very small heads back to back', False)
# ('The ACDC guitarist : his head with his hair', False)
# ('half - destroyed wings', False)
# (['Here the jaw of a beast with fangs inside its mouth', 'no eye'], True)
# ('The Sandman (in Spiderman) returning to human form', False)
# ('no meaningful NP found', False)
# (['no meaningful NP found', 'lungs hidden right there', 'Or lungs hidden right there', 'some kind of flageolet seeds'], True)
# (['no meaningful NP found', 'some kind of figure with something to leap on'], True)
# ("some kind of extraterrestrial angel going to an island because it 's got wings", False)
# ('a child about', False)
# ('seahorse', False)
# (['no meaningful NP found', 'figures with chainsaw - like arms'], True)
# ('Prussian army soldiers with spikes on their helmets', False)
# (['head', 'the prominence'], True)
# ('no meaningful NP found', False)
# (['A Mayan weapon ;', 'perhaps not a weapon a Mayan cult object', 'A Mayan weapon ; or perhaps not a weapon a Mayan cult object', 'some kind of mushroom'], True)
# ('A microscope view with the right dyes', False)
# ("Two species of insect foraging on what 's there", False)
# ("A fly 's head with something dripping from it (orange)", False)
# ('Vocal cords (green lines)', False)
# ('A character with antennae of some kind disregarding the vocal cords', False)
# (['a transaction', 'no meaningful NP found', 'a transaction or something', 'no meaningful NP found'], True)
# ('Two kinds of deformed creatures approaching', False)
# ('Two nostrils perhaps a skull hidden by everything else', False)
# (["A ghost 's head partly hidden by the rest", 'some kind of magnetic field'], True)
# (['Two islands', 'countries that reflect each other (green)'], True)
# ('A piece of Parma ham (pink)', False)
# ('Some kind of roots like the Sepultura logo (orange lines) Some kind of symbiotic matter that fuses together', False)
# ('A character with wings (green)', False)
# ('quite contemporary art like Miro', False)
# ("Two species of little bugs fighting over what 's in the middle (black)", False)
# (['Octopuses', 'alien policemen'], True)
# (['Two little suns', 'comets (yellow)'], True)
# (['Two', 'the letter Omega with a spider', 'Two caterpillars or the letter Omega with a spider', 'the tip (green)'], True)
# ('Two kinds of embryos', False)
# (['Two kinds of ants with a flame (black+yellow) catching up with the two things there (orange)', "the Ghostrider 's motorcycle"], True)
# (['strange mouths', 'some kind of sonic screwdriver'], True)
# (['Two figures with a blue ponpon', 'air (pink)'], True)
# ('The two ants', False)
# (['Two back brushes a hairbrush', 'an odd compass (orange)'], True)
# ('the two caterpillars', False)
# (['Two people supporting each other so as not to lose their balance', '(central blue)'], True)

# %% [markdown]
# To account for repetitions, since it is also possible that the speaker repeats themselves and actually utters the same response more than once, a cosine similarity function will be implemented. As of now, an appropiate cutoff value for the similarity is not set so this functionality will not be in the prototype. However, the potential use of cosine similarity would be comparing the noun phrases we got from the previous section and deleting the sentence in the pair which has the shortest length because the longer sentence may contain a bit more information, even if just by a marginal amount (as accounted by the cosine similarity).

# %%
import itertools
from sentence_transformers import SentenceTransformer, util

# %%
def cosine_similarity_dict(dict):


    embeddigngs_model = SentenceTransformer("all-MiniLM-L6-v2") 

    list_cosine_similarity = []
    list_responses = []
    for key in dict:
        list_responses.append(dict[key])

    sentence_pairs = itertools.combinations(list_responses, 2)
    for pair in sentence_pairs:

        dictionary_cosine_similarity = {"pair": None, "cosine_similarity": None}

        # print(pair[0], "\n", pair[1])
        dictionary_cosine_similarity["pair"] = pair

        embedding_sentence_1 = embeddigngs_model.encode(pair[0], convert_to_tensor=True)
        embedding_sentence_2 = embeddigngs_model.encode(pair[1], convert_to_tensor=True)

        cosine_similarity_pairs = util.cos_sim(embedding_sentence_1, embedding_sentence_2)

        dictionary_cosine_similarity["cosine_similarity"] = round(float(cosine_similarity_pairs), 3)

        list_cosine_similarity.append(dictionary_cosine_similarity)

    return list_cosine_similarity

# %%
cosine_simil = cosine_similarity_dict(list_dicts[0])
cosine_simil
# Out:
# [{'pair': ('Some kind of beetle with big wings, or it could be some kind of frog.',
#    'Some kind of iking mask with four eyes.'),
#   'cosine_similarity': 0.295},
#  {'pair': ('Some kind of beetle with big wings, or it could be some kind of frog.',
#    'Some kind of silhouette.'),
#   'cosine_similarity': 0.373},
#  {'pair': ('Some kind of beetle with big wings, or it could be some kind of frog.',
#    'A small character with an open mouth who looks surprised and his reflection there.'),
#   'cosine_similarity': 0.281},
#  {'pair': ('Some kind of iking mask with four eyes.',
#    'Some kind of silhouette.'),
#   'cosine_similarity': 0.457},
#  {'pair': ('Some kind of iking mask with four eyes.',
#    'A small character with an open mouth who looks surprised and his reflection there.'),
#   'cosine_similarity': 0.384},
#  {'pair': ('Some kind of silhouette.',
#    'A small character with an open mouth who looks surprised and his reflection there.'),
#   'cosine_similarity': 0.309}]

# %% [markdown]
# # Setting up the evaluate function using the classification models

# %%
import pickle
import numpy as np

# %% [markdown]
# ## FX

# %%
# copied from the ML development notebook

def evaluate_one_vs_rest(path, text):
    
    pipeline = pickle.load(open(path, "rb"))
    
    if "content" in path:
        # print("content found")
        possible_outcomes = ['(A)', '(Ad)', '(H)', '(Hd)', 'A', 'Ad', 'An', 'Art', 'Ay', 'Bl', 'Bt',
       'Cg', 'Cl', 'Ex', 'Fd', 'Fi', 'Ge', 'H', 'Hd', 'Hh', 'Hx', 'Id', 'Ls',
       'Na', 'Sc', 'Sx', 'Xy']
        
    elif "determinant" in path:
        # print("determinant found")
        possible_outcomes = ['C', 'C\'', 'C\'F', 'CF', 'F', 'FC', 'FC\'', 'FD', 'FMa', 'FMa-p', 'FMp',
       'FT', 'FV', 'FY', 'Fr', 'Ma', 'Ma-p', 'Mp', 'T', 'TF', 'V', 'VF', 'Y',
       'YF', 'rF']

    prediction = pipeline.predict([text])
    probabilities = pipeline.predict_proba([text]) # sometimes no prediction is given back so we can take the outcome with the highest P instead

    # print("prediction:", prediction)
    # print("probabilities:", probabilities)
    
    list_predictions = prediction.tolist()
    list_predictions = [x for sublist in list_predictions for x in sublist] # avoid lists with sublists

    
    if len(list_predictions) != len(possible_outcomes): # sanity check
        print(prediction)
        print( len(list_predictions)  )
        print(possible_outcomes)
        print( len(possible_outcomes)  )
        print("Error encountered in the predictions")
        
    results = ([possible_outcomes[i] for i in range(len(list_predictions)) if list_predictions[i] == 1]) 

    if results == []:
        # print("No result")
        i = probabilities.argmax(1).item()
        # print(ix)
        final_results = possible_outcomes[i]
    
    else:
        final_results = str(results).replace("\'", "").replace("[", "").replace("]", "")
    
    return final_results

# %%
example = list_dicts[0]["response_2"]
example
# Out:
# 'Some kind of iking mask with four eyes.'

# %%
example_np, coordination = get_np(example)
example_np
# Out:
# 'Some kind of iking mask with four eyes'

# %%
path_model_contents = r"..\Models\Contents\pipeline_contents_One-Many_V2-07-04.sav"


evaluation = evaluate_one_vs_rest(path_model_contents, example_np)
print(example_np)
print(evaluation)
# Out:
# Some kind of iking mask with four eyes
# Hd

# %%
path_model_determinants = r"..\Models\Determinants\pipeline_determinants_One-Many_V2-07-04.sav"


evaluation = evaluate_one_vs_rest(path_model_determinants,example_np)
print(example_np)
print(evaluation)
# Out:
# Some kind of iking mask with four eyes
# F

# %% [markdown]
# # Adapting the functions to classify to the way we are storing our info

# %% [markdown]
# # FX

# %%
def evaluation_list_dicts(list_dicts, model_contents=r"..\Models\Contents\pipeline_contents_One-Many_V2-07-04.sav", model_determinants=r"..\Models\Determinants\pipeline_determinants_One-Many_V2-07-04.sav"):
    """This function runs the evaluation with our first two models. 
    It takes as input the list of dictionary responses, prints the evaluation 
    and returns the content and determinant labels for each response in dictionary form.   
    """
    evaluation = []
    i = 1
    for dictionary in list_dicts:
        
        figure_number = "Figure_{}".format(i)
        
        dict_evaluation_per_figure = {}
        
        print(figure_number, "\n") 
        
        list_evaluation_figure = []
        
        j = 1
        
        for response in dictionary:
            
            sentence = dictionary[response]
            # print(dictionary[response]) #works until here

            # print(response, content, determinant)
            
            dict_eval = {}
            dict_eval["response"] = sentence
            noun_phrases, coordination = get_np(sentence)
            dict_eval["noun_phrase"] = noun_phrases

            print("Response {}: ".format(j), sentence)
            
            
            if noun_phrases == "no meaningful NP found":
                # contents = "None"
                # determinants = "None"
                dict_eval["content"] =  "None"
                dict_eval["determinant"] =  "None"
                dict_eval["coordination"] = coordination
            
            elif coordination == True:
                print("Coordination Found!")
                
                contents = []
                determinants = []
                dict_eval["coordination"] = coordination
                
                for np in noun_phrases:
                    
                    content = evaluate_one_vs_rest(model_contents, np)
                    contents.append((content, np))
                    
                    determinant = evaluate_one_vs_rest(model_determinants, np)
                    determinants.append((determinant, np))
                    
                    dict_eval["content"] = contents
                    dict_eval["determinant"] = determinants
                    
                    
                # print(response, content)
            elif coordination == False:
                # print(noun_phrases)
                contents = []
                determinants = []
                contents = evaluate_one_vs_rest(model_contents, noun_phrases)
                determinants = evaluate_one_vs_rest(model_determinants, noun_phrases)
                
                dict_eval["content"] = contents
                dict_eval["determinant"] = determinants
                dict_eval["coordination"] = coordination
                
            # dict_eval["position"] = None
            # dict_eval["colour"] = None
            
            list_evaluation_figure.append(dict_eval)
            
            print("\nNoun Phrase(s):", noun_phrases, "\nContent:", contents , "\nDeterminant:", determinants, "\n")
            
            
            j = 1 + j
            
        dict_evaluation_per_figure[figure_number] = list_evaluation_figure
        
        evaluation.append(dict_evaluation_per_figure)
        
        i = i +1
        
    return evaluation

# %%
evaluation_list_dicts(list_dicts[:2])
# Out:
# Figure_1
#
# Response 1:  Some kind of beetle with big wings, or it could be some kind of frog.
# Coordination Found!
#
# Noun Phrase(s): ['Some kind of beetle with big wings', 'some kind of frog']
# Content: [('A', 'Some kind of beetle with big wings'), ('A', 'some kind of frog')]
# Determinant: [('Ma', 'Some kind of beetle with big wings'), ('FMp', 'some kind of frog')]
#
# Response 2:  Some kind of iking mask with four eyes.
#
# Noun Phrase(s): Some kind of iking mask with four eyes
# Content: Hd
# Determinant: F
#
# Response 3:  Some kind of silhouette.
#
# Noun Phrase(s): Some kind of silhouette
# Content: Sc
# Determinant: F
#
# Response 4:  A small character with an open mouth who looks surprised and his reflection there.
# Coordination Found!
#
# Noun Phrase(s): ['A small character with an open mouth who looks surprised', 'his reflection there']
# Content: [('Id', 'A small character with an open mouth who looks surprised'), ('A', 'his reflection there')]
# Determinant: [('F', 'A small character with an open mouth who looks surprised'), ('F', 'his reflection there')]
#
# Figure_2
#
# Response 1:  Two characters making contact or fighting because there's blood or a leg has been cut off.
# Coordination Found!
#
# Noun Phrase(s): ['Two characters', 'blood', "Two characters making contact or fighting because there 's blood", 'no meaningful NP found']
# Content: [('H, Xy', 'Two characters'), ('A', 'blood'), ('H', "Two characters making contact or fighting because there 's blood"), ('A', 'no meaningful NP found')]
# Determinant: [('CF', 'Two characters'), ('F', 'blood'), ('Mp', "Two characters making contact or fighting because there 's blood"), ('F', 'no meaningful NP found')]
#
# Response 2:  Lungs.
#
# Noun Phrase(s): Lungs
# Content: An
# Determinant: FY
#
# Response 3:  A rooster's head with a crest Fighter plane, glider, jet engine fire; again, it could be a larger one sending missiles Trunk men, perhaps irrational or some kind of caterpillar with a big belly.
# Coordination Found!
#
# Noun Phrase(s): ["A rooster 's head with a crest Fighter plane glider jet engine fire", 'some kind of caterpillar with a big belly']
# Content: [('Hd', "A rooster 's head with a crest Fighter plane glider jet engine fire"), ('Id', 'some kind of caterpillar with a big belly')]
# Determinant: [('F', "A rooster 's head with a crest Fighter plane glider jet engine fire"), ('F', 'some kind of caterpillar with a big belly')]
# [{'Figure_1': [{'response': 'Some kind of beetle with big wings, or it could be some kind of frog.',
#     'noun_phrase': ['Some kind of beetle with big wings', 'some kind of frog'],
#     'coordination': True,
#     'content': [('A', 'Some kind of beetle with big wings'),
#      ('A', 'some kind of frog')],
#     'determinant': [('Ma', 'Some kind of beetle with big wings'),
#      ('FMp', 'some kind of frog')]},
#    {'response': 'Some kind of iking mask with four eyes.',
#     'noun_phrase': 'Some kind of iking mask with four eyes',
#     'content': 'Hd',
#     'determinant': 'F',
#     'coordination': False},
#    {'response': 'Some kind of silhouette.',
#     'noun_phrase': 'Some kind of silhouette',
#     'content': 'Sc',
#     'determinant': 'F',
#     'coordination': False},
#    {'response': 'A small character with an open mouth who looks surprised and his reflection there.',
#     'noun_phrase': ['A small character with an open mouth who looks surprised',
#      'his reflection there'],
#     'coordination': True,
#     'content': [('Id',
#       'A small character with an open mouth who looks surprised'),
#      ('A', 'his reflection there')],
#     'determinant': [('F',
#       'A small character with an open mouth who looks surprised'),
#      ('F', 'his reflection there')]}]},
#  {'Figure_2': [{'response': "Two characters making contact or fighting because there's blood or a leg has been cut off.",
#     'noun_phrase': ['Two characters',
#      'blood',
#      "Two characters making contact or fighting because there 's blood",
#      'no meaningful NP found'],
#     'coordination': True,
#     'content': [('H, Xy', 'Two characters'),
#      ('A', 'blood'),
#      ('H', "Two characters making contact or fighting because there 's blood"),
#      ('A', 'no meaningful NP found')],
#     'determinant': [('CF', 'Two characters'),
#      ('F', 'blood'),
#      ('Mp',
#       "Two characters making contact or fighting because there 's blood"),
#      ('F', 'no meaningful NP found')]},
#    {'response': 'Lungs.',
#     'noun_phrase': 'Lungs',
#     'content': 'An',
#     'determinant': 'FY',
#     'coordination': False},
#    {'response': "A rooster's head with a crest Fighter plane, glider, jet engine fire; again, it could be a larger one sending missiles Trunk men, perhaps irrational or some kind of caterpillar with a big belly.",
#     'noun_phrase': ["A rooster 's head with a crest Fighter plane glider jet engine fire",
#      'some kind of caterpillar with a big belly'],
#     'coordination': True,
#     'content': [('Hd',
#       "A rooster 's head with a crest Fighter plane glider jet engine fire"),
#      ('Id', 'some kind of caterpillar with a big belly')],
#     'determinant': [('F',
#       "A rooster 's head with a crest Fighter plane glider jet engine fire"),
#      ('F', 'some kind of caterpillar with a big belly')]}]}]

# %%
evaluation
# Out:
# 'F'

# %% [markdown]
# # 4 PUTTING IT ALL TOGETHER

# %% [markdown]
# Finally, putting the functions together to generate a mini-report and the corresponding results dictionary

# %%
def raw_text_response_eval(raw_text):
    
    responses = get_responses(raw_text)

    list_dicts = transform_dictionary_to_figure_list(responses)

    evaluation_dict = evaluation_list_dicts(list_dicts)
    
    return evaluation_dict

# %%
def translated_dict_response_eval(dictionary): 
    """Use this one if you are working with the demo dictionaries already done to save deepl credits"""
    
    responses = dictionary

    list_dicts = transform_dictionary_to_figure_list(responses)

    evaluation_dict = evaluation_list_dicts(list_dicts)
    
    return evaluation_dict

# %%
# raw_text_response_eval(raw_text)

# %%
evaluation = translated_dict_response_eval(demo)
# Out:
# Figure_1
#
# Response 1:  Some kind of beetle with big wings, or it could be some kind of frog.
# Coordination Found!
# Noun Phrase(s): ['Some kind of beetle with big wings', 'some kind of frog']
# Content: [('A', 'Some kind of beetle with big wings'), ('A', 'some kind of frog')]
# Determinant: [('Ma', 'Some kind of beetle with big wings'), ('FMp', 'some kind of frog')]
#
# Response 2:  Some kind of iking mask with four eyes.
#
# Noun Phrase(s): Some kind of iking mask with four eyes
# Content: Hd
# Determinant: F
#
# Response 3:  Some kind of silhouette.
#
# Noun Phrase(s): Some kind of silhouette
# Content: Sc
# Determinant: F
#
# Response 4:  A small character with an open mouth who looks surprised and his reflection there.
# Coordination Found!
#
# Noun Phrase(s): ['A small character with an open mouth who looks surprised', 'his reflection there']
# Content: [('Id', 'A small character with an open mouth who looks surprised'), ('A', 'his reflection there')]
# Determinant: [('F', 'A small character with an open mouth who looks surprised'), ('F', 'his reflection there')]
#
# Figure_2
#
# Response 1:  Two characters making contact or fighting because there's blood or a leg has been cut off.
# Coordination Found!
#
# Noun Phrase(s): ['Two characters', 'blood', "Two characters making contact or fighting because there 's blood", 'no meaningful NP found']
# Content: [('H, Xy', 'Two characters'), ('A', 'blood'), ('H', "Two characters making contact or fighting because there 's blood"), ('A', 'no meaningful NP found')]
# Determinant: [('CF', 'Two characters'), ('F', 'blood'), ('Mp', "Two characters making contact or fighting because there 's blood"), ('F', 'no meaningful NP found')]
#
# Response 2:  Lungs.
#
# Noun Phrase(s): Lungs
# Content: An
# Determinant: FY
#
# Response 3:  A rooster's head with a crest Fighter plane, glider, jet engine fire; again, it could be a larger one sending missiles Trunk men, perhaps irrational or some kind of caterpillar with a big belly.
# Coordination Found!
#
# Noun Phrase(s): ["A rooster 's head with a crest Fighter plane glider jet engine fire", 'some kind of caterpillar with a big belly']
# Content: [('Hd', "A rooster 's head with a crest Fighter plane glider jet engine fire"), ('Id', 'some kind of caterpillar with a big belly')]
# Determinant: [('F', "A rooster 's head with a crest Fighter plane glider jet engine fire"), ('F', 'some kind of caterpillar with a big belly')]
#
# Figure_3
#
# Response 1:  Two oddly shaped guitars with twisted necks.
#
# Noun Phrase(s): Two
# Content: H, Xy
# Determinant: CF
#
# Response 2:  Again, two figures face to face, strangely constituted, like Picasso.
#
# Noun Phrase(s): two figures
# Content: H
# Determinant: FC
#
# Response 3:  Or two figures as one.
# Coordination Found!
#
# Noun Phrase(s): ['no meaningful NP found', 'two figures as one']
# Content: [('A', 'no meaningful NP found'), ('H', 'two figures as one')]
# Determinant: [('F', 'no meaningful NP found'), ('Ma', 'two figures as one')]
#
# Response 4:  Two kinds of missiles or torpedoes.
# Coordination Found!
#
# Noun Phrase(s): ['Two kinds of missiles', 'no meaningful NP found']
# Content: [('H', 'Two kinds of missiles'), ('A', 'no meaningful NP found')]
# Determinant: [('Mp', 'Two kinds of missiles'), ('F', 'no meaningful NP found')]
#
# Response 5:  Lungs or a butterfly.
# Coordination Found!
#
# Noun Phrase(s): ['Lungs', 'a butterfly']
# Content: [('An', 'Lungs'), ('A', 'a butterfly')]
# Determinant: [('FY', 'Lungs'), ('F', 'a butterfly')]
#
# Response 6:  Just part of an old man with his cane, or an embryo.
# Coordination Found!
#
# Noun Phrase(s): ['Just part of an old man with his cane', 'an embryo']
# Content: [('Sc', 'Just part of an old man with his cane'), ('A', 'an embryo')]
# Determinant: [('F', 'Just part of an old man with his cane'), ('F', 'an embryo')]
#
# Response 7:  Some kind of big beast, you can see the inside of its body, the mandibles.
#
# Noun Phrase(s): big beast
# Content: A
# Determinant: F
#
# Figure_4
#
# Response 1:  I see yet another bizarre creature, a colossus, with wings there and strange legs.
# Coordination Found!
#
# Noun Phrase(s): ['a colossus', 'strange legs']
# Content: [('A', 'a colossus'), ('Hd, Hh', 'strange legs')]
# Determinant: [('F', 'a colossus'), ('Mp, VF', 'strange legs')]
#
# Response 2:  Two figures under a kind of burka.
#
# Noun Phrase(s): Two figures under a kind of burka
# Content: H
# Determinant: Ma
#
# Response 3:  The fly's head (film).
#
# Noun Phrase(s): The fly 's head (film)
# Content: (Hd)
# Determinant: F
#
# Response 4:  A baby crocodile's head, or a pig's since there's no ear, or maybe a mole, some kind of trunk.
# Coordination Found!
#
# Noun Phrase(s): ["A baby crocodile 's head", "a pig 's since there 's no ear", "A baby crocodile 's head or a pig 's since there 's no ear", 'maybe a mole some kind of trunk']
# Content: [('(Hd)', "A baby crocodile 's head"), ('Ad', "a pig 's since there 's no ear"), ('Ad', "A baby crocodile 's head or a pig 's since there 's no ear"), ('(H)', 'maybe a mole some kind of trunk')]
# Determinant: [('Mp', "A baby crocodile 's head"), ('FMa', "a pig 's since there 's no ear"), ('F', "A baby crocodile 's head or a pig 's since there 's no ear"), ('Mp', 'maybe a mole some kind of trunk')]
#
# Figure_5
#
# Response 1:  I also see a sort of cross between a bat and a snail, and the legs are a bit strange.
# Coordination Found!
#
# Noun Phrase(s): ['cross', 'a snail', 'cross', 'the legs']
# Content: [('A', 'cross'), ('(A), (Ad)', 'a snail'), ('A', 'cross'), ('Hd', 'the legs')]
# Determinant: [('F', 'cross'), ('F', 'a snail'), ('F', 'cross'), ('Mp', 'the legs')]
#
# Response 2:  Otherwise, I don't see anything else.
#
# Noun Phrase(s): no meaningful NP found
# Content: [('A', 'cross'), ('(A), (Ad)', 'a snail'), ('A', 'cross'), ('Hd', 'the legs')]
# Determinant: [('F', 'cross'), ('F', 'a snail'), ('F', 'cross'), ('Mp', 'the legs')]
#
# Response 3:  Maybe two very small heads, back to back.
#
# Noun Phrase(s): Maybe two very small heads back to back
# Content: H
# Determinant: Fr
#
# Response 4:  The ACDC guitarist: his head with his hair.
#
# Noun Phrase(s): The ACDC guitarist : his head with his hair
# Content: Id
# Determinant: F
#
# Figure_6
#
# Response 1:  A rather bizarre dragonfly with half-destroyed wings.
#
# Noun Phrase(s): half - destroyed wings
# Content: (A)
# Determinant: Ma
#
# Response 2:  Here, the jaw of a beast with fangs inside its mouth, but there's no eye, so maybe it's a carnivorous plant.
# Coordination Found!
#
# Noun Phrase(s): ['Here the jaw of a beast with fangs inside its mouth', 'no eye']
# Content: [('Id', 'Here the jaw of a beast with fangs inside its mouth'), ('Hd', 'no eye')]
# Determinant: [('F', 'Here the jaw of a beast with fangs inside its mouth'), ('FD', 'no eye')]
#
# Response 3:  The Sandman (in Spiderman) returning to human form.
#
# Noun Phrase(s): The Sandman (in Spiderman) returning to human form
# Content: Na
# Determinant: F
#
# Response 4:  Otherwise, that's all I can see.
#
# Noun Phrase(s): no meaningful NP found
# Content: Na
# Determinant: F
#
# Response 5:  Or lungs hidden right there, or some kind of flageolet seeds.
# Coordination Found!
#
# Noun Phrase(s): ['no meaningful NP found', 'lungs hidden right there', 'Or lungs hidden right there', 'some kind of flageolet seeds']
# Content: [('A', 'no meaningful NP found'), ('An', 'lungs hidden right there'), ('An', 'Or lungs hidden right there'), ('Sc', 'some kind of flageolet seeds')]
# Determinant: [('F', 'no meaningful NP found'), ('FY', 'lungs hidden right there'), ('FY', 'Or lungs hidden right there'), ('F', 'some kind of flageolet seeds')]
#
# Response 6:  Or some kind of figure with something to leap on.
# Coordination Found!
#
# Noun Phrase(s): ['no meaningful NP found', 'some kind of figure with something to leap on']
# Content: [('A', 'no meaningful NP found'), ('Na', 'some kind of figure with something to leap on')]
# Determinant: [('F', 'no meaningful NP found'), ('Ma', 'some kind of figure with something to leap on')]
#
# Response 7:  Finally, maybe it's some kind of extraterrestrial angel going to an island because it's got wings.
#
# Noun Phrase(s): some kind of extraterrestrial angel going to an island because it 's got wings
# Content: Ls
# Determinant: F
#
# Response 8:  He comes down that way, so maybe it's a child about to be born.
#
# Noun Phrase(s): a child about
# Content: H
# Determinant: F
#
# Figure_7
#
# Response 1:  Two species of seahorse with a proboscis here; they're both connected by something that's there; they look frozen because there are stalactites, like perhaps prehistoric animals that have been frozen.
#
# Noun Phrase(s): seahorse
# Content: A
# Determinant: F
#
# Response 2:  Or over there, you can see some kind of figures with chainsaw-like arms trying to get closer.
# Coordination Found!
#
# Noun Phrase(s): ['no meaningful NP found', 'figures with chainsaw - like arms']
# Content: [('A', 'no meaningful NP found'), ('(H)', 'figures with chainsaw - like arms')]
# Determinant: [('F', 'no meaningful NP found'), ('F', 'figures with chainsaw - like arms')]
#
# Response 3:  Prussian army soldiers with spikes on their helmets.
#
# Noun Phrase(s): Prussian army soldiers with spikes on their helmets
# Content: Id
# Determinant: F
#
# Response 4:  Here we can see a kind of head with a snout, but given the prominence, it could be the king's jester.
# Coordination Found!
#
# Noun Phrase(s): ['head', 'the prominence']
# Content: [('(Hd)', 'head'), ('A', 'the prominence')]
# Determinant: [('Mp', 'head'), ('F', 'the prominence')]
#
# Response 5:  If you integrate the white, you can see a mask.
#
# Noun Phrase(s): no meaningful NP found
# Content: [('(Hd)', 'head'), ('A', 'the prominence')]
# Determinant: [('Mp', 'head'), ('F', 'the prominence')]
#
# Response 6:  A Mayan weapon; or perhaps not a weapon, a Mayan cult object or some kind of mushroom.
# Coordination Found!
#
# Noun Phrase(s): ['A Mayan weapon ;', 'perhaps not a weapon a Mayan cult object', 'A Mayan weapon ; or perhaps not a weapon a Mayan cult object', 'some kind of mushroom']
# Content: [('A', 'A Mayan weapon ;'), ('A', 'perhaps not a weapon a Mayan cult object'), ('A', 'A Mayan weapon ; or perhaps not a weapon a Mayan cult object'), ('Bt', 'some kind of mushroom')]
# Determinant: [('F', 'A Mayan weapon ;'), ('F', 'perhaps not a weapon a Mayan cult object'), ('F', 'A Mayan weapon ; or perhaps not a weapon a Mayan cult object'), ('F', 'some kind of mushroom')]
#
# Figure_8
#
# Response 1:  A microscope view with the right dyes.
#
# Noun Phrase(s): A microscope view with the right dyes
# Content: A
# Determinant: F
#
# Response 2:  Two species of insect foraging on what's there.
#
# Noun Phrase(s): Two species of insect foraging on what 's there
# Content: A
# Determinant: F
#
# Response 3:  A fly's head with something dripping from it (orange).
#
# Noun Phrase(s): A fly 's head with something dripping from it (orange)
# Content: Id
# Determinant: F
#
# Response 4:  Vocal cords (green lines).
#
# Noun Phrase(s): Vocal cords (green lines)
# Content: A
# Determinant: F
#
# Response 5:  A character with antennae of some kind, disregarding the vocal cords.
#
# Noun Phrase(s): A character with antennae of some kind disregarding the vocal cords
# Content: A
# Determinant: FD
#
# Response 6:  Two chameleons climbing a mountain; it looks like they're shaking hands; there's a transaction or something: they're giving money or recharging energy.
# Coordination Found!
#
# Noun Phrase(s): ['a transaction', 'no meaningful NP found', 'a transaction or something', 'no meaningful NP found']
# Content: [('A', 'a transaction'), ('A', 'no meaningful NP found'), ('H', 'a transaction or something'), ('A', 'no meaningful NP found')]
# Determinant: [('F', 'a transaction'), ('F', 'no meaningful NP found'), ('Ma', 'a transaction or something'), ('F', 'no meaningful NP found')]
#
# Figure_9
#
# Response 1:  Two kinds of deformed creatures approaching.
#
# Noun Phrase(s): Two kinds of deformed creatures approaching
# Content: H
# Determinant: Mp
#
# Response 2:  Two nostrils, perhaps a skull hidden by everything else.
#
# Noun Phrase(s): Two nostrils perhaps a skull hidden by everything else
# Content: H
# Determinant: Mp
#
# Response 3:  A ghost's head partly hidden by the rest, or some kind of magnetic field.
# Coordination Found!
#
# Noun Phrase(s): ["A ghost 's head partly hidden by the rest", 'some kind of magnetic field']
# Content: [('(Hd)', "A ghost 's head partly hidden by the rest"), ('Sc', 'some kind of magnetic field')]
# Determinant: [('F', "A ghost 's head partly hidden by the rest"), ('F', 'some kind of magnetic field')]
#
# Response 4:  Two islands or countries that reflect each other (green).
# Coordination Found!
#
# Noun Phrase(s): ['Two islands', 'countries that reflect each other (green)']
# Content: [('H, Xy', 'Two islands'), ('An', 'countries that reflect each other (green)')]
# Determinant: [('CF', 'Two islands'), ("FC'", 'countries that reflect each other (green)')]
#
# Response 5:  A piece of Parma ham (pink).
#
# Noun Phrase(s): A piece of Parma ham (pink)
# Content: Sc
# Determinant: F
#
# Response 6:  Some kind of roots, like the Sepultura logo (orange lines) Some kind of symbiotic matter that fuses together.
#
# Noun Phrase(s): Some kind of roots like the Sepultura logo (orange lines) Some kind of symbiotic matter that fuses together
# Content: Sc
# Determinant: F
#
# Response 7:  A character with wings (green).
#
# Noun Phrase(s): A character with wings (green)
# Content: Hx
# Determinant: Ma
#
# Figure_10
#
# Response 1:  It's quite contemporary art, like Miro.
#
# Noun Phrase(s): quite contemporary art like Miro
# Content: (H)
# Determinant: Mp
#
# Response 2:  Two species of little bugs fighting over what's in the middle (black).
#
# Noun Phrase(s): Two species of little bugs fighting over what 's in the middle (black)
# Content: Sc
# Determinant: F
#
# Response 3:  Octopuses or alien policemen trying to separate them (blue).
# Coordination Found!
#
# Noun Phrase(s): ['Octopuses', 'alien policemen']
# Content: [('A', 'Octopuses'), ('An', 'alien policemen')]
# Determinant: [('F', 'Octopuses'), ('FC', 'alien policemen')]
#
# Response 4:  Two little suns or comets (yellow).
# Coordination Found!
#
# Noun Phrase(s): ['Two little suns', 'comets (yellow)']
# Content: [('H, Xy', 'Two little suns'), ('A', 'comets (yellow)')]
# Determinant: [('CF', 'Two little suns'), ('F', 'comets (yellow)')]
#
# Response 5:  Two caterpillars or the letter Omega with a spider or tuning fork at the tip (green).
# Coordination Found!
#
# Noun Phrase(s): ['Two', 'the letter Omega with a spider', 'Two caterpillars or the letter Omega with a spider', 'the tip (green)']
# Content: [('H, Xy', 'Two'), ('Id', 'the letter Omega with a spider'), ('(A)', 'Two caterpillars or the letter Omega with a spider'), ('A', 'the tip (green)')]
# Determinant: [('CF', 'Two'), ('F', 'the letter Omega with a spider'), ('FMp', 'Two caterpillars or the letter Omega with a spider'), ('F', 'the tip (green)')]
#
# Response 6:  Two kinds of embryos spitting out blue matter (pink).
#
# Noun Phrase(s): Two kinds of embryos
# Content: H
# Determinant: Mp
#
# Response 7:  Two kinds of ants with a flame (black+yellow), catching up with the two things there (orange) or the Ghostrider's motorcycle.
# Coordination Found!
#
# Noun Phrase(s): ['Two kinds of ants with a flame (black+yellow) catching up with the two things there (orange)', "the Ghostrider 's motorcycle"]
# Content: [('H', 'Two kinds of ants with a flame (black+yellow) catching up with the two things there (orange)'), ('A', "the Ghostrider 's motorcycle")]
# Determinant: [('F', 'Two kinds of ants with a flame (black+yellow) catching up with the two things there (orange)'), ('F', "the Ghostrider 's motorcycle")]
#
# Response 8:  I also see two eyes with strange mouths: the green is the horns, the blue the mouth, the gray an electric razor or some kind of sonic screwdriver.
# Coordination Found!
#
# Noun Phrase(s): ['strange mouths', 'some kind of sonic screwdriver']
# Content: [('A', 'strange mouths'), ('Sc', 'some kind of sonic screwdriver')]
# Determinant: [('F', 'strange mouths'), ('F', 'some kind of sonic screwdriver')]
#
# Response 9:  Two figures with a blue ponpon are liquefying, perhaps made of skin and air (pink).
# Coordination Found!
#
# Noun Phrase(s): ['Two figures with a blue ponpon', 'air (pink)']
# Content: [('H', 'Two figures with a blue ponpon'), ('A', 'air (pink)')]
# Determinant: [('F', 'Two figures with a blue ponpon'), ('F', 'air (pink)')]
#
# Response 10:  The two ants will try to put a cap on them to stop them deflating.
#
# Noun Phrase(s): The two ants
# Content: H
# Determinant: FC
#
# Response 11:  Two back brushes, a hairbrush or an odd compass (orange).
# Coordination Found!
#
# Noun Phrase(s): ['Two back brushes a hairbrush', 'an odd compass (orange)']
# Content: [('H', 'Two back brushes a hairbrush'), ('A', 'an odd compass (orange)')]
# Determinant: [('Mp', 'Two back brushes a hairbrush'), ('F', 'an odd compass (orange)')]
#
# Response 12:  Finally, the two caterpillars have their astral projections coming out of their bodies.
#
# Noun Phrase(s): the two caterpillars
# Content: H
# Determinant: FC
#
# Response 13:  Two people supporting each other so as not to lose their balance and fall (central blue).
# Coordination Found!
#
# Noun Phrase(s): ['Two people supporting each other so as not to lose their balance', '(central blue)']
# Content: [('H', 'Two people supporting each other so as not to lose their balance'), ('A', '(central blue)')]
# Determinant: [('Ma', 'Two people supporting each other so as not to lose their balance'), ('F', '(central blue)')]

# %%
evaluation
# Out:
# [{'Figure_1': [{'response': 'Some kind of beetle with big wings, or it could be some kind of frog.',
#     'noun_phrase': ['Some kind of beetle with big wings', 'some kind of frog'],
#     'coordination': True,
#     'content': [('A', 'Some kind of beetle with big wings'),
#      ('A', 'some kind of frog')],
#     'determinant': [('Ma', 'Some kind of beetle with big wings'),
#      ('FMp', 'some kind of frog')]},
#    {'response': 'Some kind of iking mask with four eyes.',
#     'noun_phrase': 'Some kind of iking mask with four eyes',
#     'content': 'Hd',
#     'determinant': 'F',
#     'coordination': False},
#    {'response': 'Some kind of silhouette.',
#     'noun_phrase': 'Some kind of silhouette',
#     'content': 'Sc',
#     'determinant': 'F',
#     'coordination': False},
#    {'response': 'A small character with an open mouth who looks surprised and his reflection there.',
#     'noun_phrase': ['A small character with an open mouth who looks surprised',
#      'his reflection there'],
#     'coordination': True,
#     'content': [('Id',
#       'A small character with an open mouth who looks surprised'),
#      ('A', 'his reflection there')],
#     'determinant': [('F',
#       'A small character with an open mouth who looks surprised'),
#      ('F', 'his reflection there')]}]},
#  {'Figure_2': [{'response': "Two characters making contact or fighting because there's blood or a leg has been cut off.",
#     'noun_phrase': ['Two characters',
#      'blood',
#      "Two characters making contact or fighting because there 's blood",
#      'no meaningful NP found'],
#     'coordination': True,
#     'content': [('H, Xy', 'Two characters'),
#      ('A', 'blood'),
#      ('H', "Two characters making contact or fighting because there 's blood"),
#      ('A', 'no meaningful NP found')],
#     'determinant': [('CF', 'Two characters'),
#      ('F', 'blood'),
#      ('Mp',
#       "Two characters making contact or fighting because there 's blood"),
#      ('F', 'no meaningful NP found')]},
#    {'response': 'Lungs.',
#     'noun_phrase': 'Lungs',
#     'content': 'An',
#     'determinant': 'FY',
#     'coordination': False},
#    {'response': "A rooster's head with a crest Fighter plane, glider, jet engine fire; again, it could be a larger one sending missiles Trunk men, perhaps irrational or some kind of caterpillar with a big belly.",
#     'noun_phrase': ["A rooster 's head with a crest Fighter plane glider jet engine fire",
#      'some kind of caterpillar with a big belly'],
#     'coordination': True,
#     'content': [('Hd',
#       "A rooster 's head with a crest Fighter plane glider jet engine fire"),
#      ('Id', 'some kind of caterpillar with a big belly')],
#     'determinant': [('F',
#       "A rooster 's head with a crest Fighter plane glider jet engine fire"),
#      ('F', 'some kind of caterpillar with a big belly')]}]},
#  {'Figure_3': [{'response': 'Two oddly shaped guitars with twisted necks.',
#     'noun_phrase': 'Two',
#     'content': 'H, Xy',
#     'determinant': 'CF',
#     'coordination': False},
#    {'response': 'Again, two figures face to face, strangely constituted, like Picasso.',
#     'noun_phrase': 'two figures',
#     'content': 'H',
#     'determinant': 'FC',
#     'coordination': False},
#    {'response': 'Or two figures as one.',
#     'noun_phrase': ['no meaningful NP found', 'two figures as one'],
#     'coordination': True,
#     'content': [('A', 'no meaningful NP found'), ('H', 'two figures as one')],
#     'determinant': [('F', 'no meaningful NP found'),
#      ('Ma', 'two figures as one')]},
#    {'response': 'Two kinds of missiles or torpedoes.',
#     'noun_phrase': ['Two kinds of missiles', 'no meaningful NP found'],
#     'coordination': True,
#     'content': [('H', 'Two kinds of missiles'),
#      ('A', 'no meaningful NP found')],
#     'determinant': [('Mp', 'Two kinds of missiles'),
#      ('F', 'no meaningful NP found')]},
#    {'response': 'Lungs or a butterfly.',
#     'noun_phrase': ['Lungs', 'a butterfly'],
#     'coordination': True,
#     'content': [('An', 'Lungs'), ('A', 'a butterfly')],
#     'determinant': [('FY', 'Lungs'), ('F', 'a butterfly')]},
#    {'response': 'Just part of an old man with his cane, or an embryo.',
#     'noun_phrase': ['Just part of an old man with his cane', 'an embryo'],
#     'coordination': True,
#     'content': [('Sc', 'Just part of an old man with his cane'),
#      ('A', 'an embryo')],
#     'determinant': [('F', 'Just part of an old man with his cane'),
#      ('F', 'an embryo')]},
#    {'response': 'Some kind of big beast, you can see the inside of its body, the mandibles.',
#     'noun_phrase': 'big beast',
#     'content': 'A',
#     'determinant': 'F',
#     'coordination': False}]},
#  {'Figure_4': [{'response': 'I see yet another bizarre creature, a colossus, with wings there and strange legs.',
#     'noun_phrase': ['a colossus', 'strange legs'],
#     'coordination': True,
#     'content': [('A', 'a colossus'), ('Hd, Hh', 'strange legs')],
#     'determinant': [('F', 'a colossus'), ('Mp, VF', 'strange legs')]},
#    {'response': 'Two figures under a kind of burka.',
#     'noun_phrase': 'Two figures under a kind of burka',
#     'content': 'H',
#     'determinant': 'Ma',
#     'coordination': False},
#    {'response': "The fly's head (film).",
#     'noun_phrase': "The fly 's head (film)",
#     'content': '(Hd)',
#     'determinant': 'F',
#     'coordination': False},
#    {'response': "A baby crocodile's head, or a pig's since there's no ear, or maybe a mole, some kind of trunk.",
#     'noun_phrase': ["A baby crocodile 's head",
#      "a pig 's since there 's no ear",
#      "A baby crocodile 's head or a pig 's since there 's no ear",
#      'maybe a mole some kind of trunk'],
#     'coordination': True,
#     'content': [('(Hd)', "A baby crocodile 's head"),
#      ('Ad', "a pig 's since there 's no ear"),
#      ('Ad', "A baby crocodile 's head or a pig 's since there 's no ear"),
#      ('(H)', 'maybe a mole some kind of trunk')],
#     'determinant': [('Mp', "A baby crocodile 's head"),
#      ('FMa', "a pig 's since there 's no ear"),
#      ('F', "A baby crocodile 's head or a pig 's since there 's no ear"),
#      ('Mp', 'maybe a mole some kind of trunk')]}]},
#  {'Figure_5': [{'response': 'I also see a sort of cross between a bat and a snail, and the legs are a bit strange.',
#     'noun_phrase': ['cross', 'a snail', 'cross', 'the legs'],
#     'coordination': True,
#     'content': [('A', 'cross'),
#      ('(A), (Ad)', 'a snail'),
#      ('A', 'cross'),
#      ('Hd', 'the legs')],
#     'determinant': [('F', 'cross'),
#      ('F', 'a snail'),
#      ('F', 'cross'),
#      ('Mp', 'the legs')]},
#    {'response': "Otherwise, I don't see anything else.",
#     'noun_phrase': 'no meaningful NP found',
#     'content': 'None',
#     'determinant': 'None',
#     'coordination': False},
#    {'response': 'Maybe two very small heads, back to back.',
#     'noun_phrase': 'Maybe two very small heads back to back',
#     'content': 'H',
#     'determinant': 'Fr',
#     'coordination': False},
#    {'response': 'The ACDC guitarist: his head with his hair.',
#     'noun_phrase': 'The ACDC guitarist : his head with his hair',
#     'content': 'Id',
#     'determinant': 'F',
#     'coordination': False}]},
#  {'Figure_6': [{'response': 'A rather bizarre dragonfly with half-destroyed wings.',
#     'noun_phrase': 'half - destroyed wings',
#     'content': '(A)',
#     'determinant': 'Ma',
#     'coordination': False},
#    {'response': "Here, the jaw of a beast with fangs inside its mouth, but there's no eye, so maybe it's a carnivorous plant.",
#     'noun_phrase': ['Here the jaw of a beast with fangs inside its mouth',
#      'no eye'],
#     'coordination': True,
#     'content': [('Id', 'Here the jaw of a beast with fangs inside its mouth'),
#      ('Hd', 'no eye')],
#     'determinant': [('F',
#       'Here the jaw of a beast with fangs inside its mouth'),
#      ('FD', 'no eye')]},
#    {'response': 'The Sandman (in Spiderman) returning to human form.',
#     'noun_phrase': 'The Sandman (in Spiderman) returning to human form',
#     'content': 'Na',
#     'determinant': 'F',
#     'coordination': False},
#    {'response': "Otherwise, that's all I can see.",
#     'noun_phrase': 'no meaningful NP found',
#     'content': 'None',
#     'determinant': 'None',
#     'coordination': False},
#    {'response': 'Or lungs hidden right there, or some kind of flageolet seeds.',
#     'noun_phrase': ['no meaningful NP found',
#      'lungs hidden right there',
#      'Or lungs hidden right there',
#      'some kind of flageolet seeds'],
#     'coordination': True,
#     'content': [('A', 'no meaningful NP found'),
#      ('An', 'lungs hidden right there'),
#      ('An', 'Or lungs hidden right there'),
#      ('Sc', 'some kind of flageolet seeds')],
#     'determinant': [('F', 'no meaningful NP found'),
#      ('FY', 'lungs hidden right there'),
#      ('FY', 'Or lungs hidden right there'),
#      ('F', 'some kind of flageolet seeds')]},
#    {'response': 'Or some kind of figure with something to leap on.',
#     'noun_phrase': ['no meaningful NP found',
#      'some kind of figure with something to leap on'],
#     'coordination': True,
#     'content': [('A', 'no meaningful NP found'),
#      ('Na', 'some kind of figure with something to leap on')],
#     'determinant': [('F', 'no meaningful NP found'),
#      ('Ma', 'some kind of figure with something to leap on')]},
#    {'response': "Finally, maybe it's some kind of extraterrestrial angel going to an island because it's got wings.",
#     'noun_phrase': "some kind of extraterrestrial angel going to an island because it 's got wings",
#     'content': 'Ls',
#     'determinant': 'F',
#     'coordination': False},
#    {'response': "He comes down that way, so maybe it's a child about to be born.",
#     'noun_phrase': 'a child about',
#     'content': 'H',
#     'determinant': 'F',
#     'coordination': False}]},
#  {'Figure_7': [{'response': "Two species of seahorse with a proboscis here; they're both connected by something that's there; they look frozen because there are stalactites, like perhaps prehistoric animals that have been frozen.",
#     'noun_phrase': 'seahorse',
#     'content': 'A',
#     'determinant': 'F',
#     'coordination': False},
#    {'response': 'Or over there, you can see some kind of figures with chainsaw-like arms trying to get closer.',
#     'noun_phrase': ['no meaningful NP found',
#      'figures with chainsaw - like arms'],
#     'coordination': True,
#     'content': [('A', 'no meaningful NP found'),
#      ('(H)', 'figures with chainsaw - like arms')],
#     'determinant': [('F', 'no meaningful NP found'),
#      ('F', 'figures with chainsaw - like arms')]},
#    {'response': 'Prussian army soldiers with spikes on their helmets.',
#     'noun_phrase': 'Prussian army soldiers with spikes on their helmets',
#     'content': 'Id',
#     'determinant': 'F',
#     'coordination': False},
#    {'response': "Here we can see a kind of head with a snout, but given the prominence, it could be the king's jester.",
#     'noun_phrase': ['head', 'the prominence'],
#     'coordination': True,
#     'content': [('(Hd)', 'head'), ('A', 'the prominence')],
#     'determinant': [('Mp', 'head'), ('F', 'the prominence')]},
#    {'response': 'If you integrate the white, you can see a mask.',
#     'noun_phrase': 'no meaningful NP found',
#     'content': 'None',
#     'determinant': 'None',
#     'coordination': False},
#    {'response': 'A Mayan weapon; or perhaps not a weapon, a Mayan cult object or some kind of mushroom.',
#     'noun_phrase': ['A Mayan weapon ;',
#      'perhaps not a weapon a Mayan cult object',
#      'A Mayan weapon ; or perhaps not a weapon a Mayan cult object',
#      'some kind of mushroom'],
#     'coordination': True,
#     'content': [('A', 'A Mayan weapon ;'),
#      ('A', 'perhaps not a weapon a Mayan cult object'),
#      ('A', 'A Mayan weapon ; or perhaps not a weapon a Mayan cult object'),
#      ('Bt', 'some kind of mushroom')],
#     'determinant': [('F', 'A Mayan weapon ;'),
#      ('F', 'perhaps not a weapon a Mayan cult object'),
#      ('F', 'A Mayan weapon ; or perhaps not a weapon a Mayan cult object'),
#      ('F', 'some kind of mushroom')]}]},
#  {'Figure_8': [{'response': 'A microscope view with the right dyes.',
#     'noun_phrase': 'A microscope view with the right dyes',
#     'content': 'A',
#     'determinant': 'F',
#     'coordination': False},
#    {'response': "Two species of insect foraging on what's there.",
#     'noun_phrase': "Two species of insect foraging on what 's there",
#     'content': 'A',
#     'determinant': 'F',
#     'coordination': False},
#    {'response': "A fly's head with something dripping from it (orange).",
#     'noun_phrase': "A fly 's head with something dripping from it (orange)",
#     'content': 'Id',
#     'determinant': 'F',
#     'coordination': False},
#    {'response': 'Vocal cords (green lines).',
#     'noun_phrase': 'Vocal cords (green lines)',
#     'content': 'A',
#     'determinant': 'F',
#     'coordination': False},
#    {'response': 'A character with antennae of some kind, disregarding the vocal cords.',
#     'noun_phrase': 'A character with antennae of some kind disregarding the vocal cords',
#     'content': 'A',
#     'determinant': 'FD',
#     'coordination': False},
#    {'response': "Two chameleons climbing a mountain; it looks like they're shaking hands; there's a transaction or something: they're giving money or recharging energy.",
#     'noun_phrase': ['a transaction',
#      'no meaningful NP found',
#      'a transaction or something',
#      'no meaningful NP found'],
#     'coordination': True,
#     'content': [('A', 'a transaction'),
#      ('A', 'no meaningful NP found'),
#      ('H', 'a transaction or something'),
#      ('A', 'no meaningful NP found')],
#     'determinant': [('F', 'a transaction'),
#      ('F', 'no meaningful NP found'),
#      ('Ma', 'a transaction or something'),
#      ('F', 'no meaningful NP found')]}]},
#  {'Figure_9': [{'response': 'Two kinds of deformed creatures approaching.',
#     'noun_phrase': 'Two kinds of deformed creatures approaching',
#     'content': 'H',
#     'determinant': 'Mp',
#     'coordination': False},
#    {'response': 'Two nostrils, perhaps a skull hidden by everything else.',
#     'noun_phrase': 'Two nostrils perhaps a skull hidden by everything else',
#     'content': 'H',
#     'determinant': 'Mp',
#     'coordination': False},
#    {'response': "A ghost's head partly hidden by the rest, or some kind of magnetic field.",
#     'noun_phrase': ["A ghost 's head partly hidden by the rest",
#      'some kind of magnetic field'],
#     'coordination': True,
#     'content': [('(Hd)', "A ghost 's head partly hidden by the rest"),
#      ('Sc', 'some kind of magnetic field')],
#     'determinant': [('F', "A ghost 's head partly hidden by the rest"),
#      ('F', 'some kind of magnetic field')]},
#    {'response': 'Two islands or countries that reflect each other (green).',
#     'noun_phrase': ['Two islands',
#      'countries that reflect each other (green)'],
#     'coordination': True,
#     'content': [('H, Xy', 'Two islands'),
#      ('An', 'countries that reflect each other (green)')],
#     'determinant': [('CF', 'Two islands'),
#      ("FC'", 'countries that reflect each other (green)')]},
#    {'response': 'A piece of Parma ham (pink).',
#     'noun_phrase': 'A piece of Parma ham (pink)',
#     'content': 'Sc',
#     'determinant': 'F',
#     'coordination': False},
#    {'response': 'Some kind of roots, like the Sepultura logo (orange lines) Some kind of symbiotic matter that fuses together.',
#     'noun_phrase': 'Some kind of roots like the Sepultura logo (orange lines) Some kind of symbiotic matter that fuses together',
#     'content': 'Sc',
#     'determinant': 'F',
#     'coordination': False},
#    {'response': 'A character with wings (green).',
#     'noun_phrase': 'A character with wings (green)',
#     'content': 'Hx',
#     'determinant': 'Ma',
#     'coordination': False}]},
#  {'Figure_10': [{'response': "It's quite contemporary art, like Miro.",
#     'noun_phrase': 'quite contemporary art like Miro',
#     'content': '(H)',
#     'determinant': 'Mp',
#     'coordination': False},
#    {'response': "Two species of little bugs fighting over what's in the middle (black).",
#     'noun_phrase': "Two species of little bugs fighting over what 's in the middle (black)",
#     'content': 'Sc',
#     'determinant': 'F',
#     'coordination': False},
#    {'response': 'Octopuses or alien policemen trying to separate them (blue).',
#     'noun_phrase': ['Octopuses', 'alien policemen'],
#     'coordination': True,
#     'content': [('A', 'Octopuses'), ('An', 'alien policemen')],
#     'determinant': [('F', 'Octopuses'), ('FC', 'alien policemen')]},
#    {'response': 'Two little suns or comets (yellow).',
#     'noun_phrase': ['Two little suns', 'comets (yellow)'],
#     'coordination': True,
#     'content': [('H, Xy', 'Two little suns'), ('A', 'comets (yellow)')],
#     'determinant': [('CF', 'Two little suns'), ('F', 'comets (yellow)')]},
#    {'response': 'Two caterpillars or the letter Omega with a spider or tuning fork at the tip (green).',
#     'noun_phrase': ['Two',
#      'the letter Omega with a spider',
#      'Two caterpillars or the letter Omega with a spider',
#      'the tip (green)'],
#     'coordination': True,
#     'content': [('H, Xy', 'Two'),
#      ('Id', 'the letter Omega with a spider'),
#      ('(A)', 'Two caterpillars or the letter Omega with a spider'),
#      ('A', 'the tip (green)')],
#     'determinant': [('CF', 'Two'),
#      ('F', 'the letter Omega with a spider'),
#      ('FMp', 'Two caterpillars or the letter Omega with a spider'),
#      ('F', 'the tip (green)')]},
#    {'response': 'Two kinds of embryos spitting out blue matter (pink).',
#     'noun_phrase': 'Two kinds of embryos',
#     'content': 'H',
#     'determinant': 'Mp',
#     'coordination': False},
#    {'response': "Two kinds of ants with a flame (black+yellow), catching up with the two things there (orange) or the Ghostrider's motorcycle.",
#     'noun_phrase': ['Two kinds of ants with a flame (black+yellow) catching up with the two things there (orange)',
#      "the Ghostrider 's motorcycle"],
#     'coordination': True,
#     'content': [('H',
#       'Two kinds of ants with a flame (black+yellow) catching up with the two things there (orange)'),
#      ('A', "the Ghostrider 's motorcycle")],
#     'determinant': [('F',
#       'Two kinds of ants with a flame (black+yellow) catching up with the two things there (orange)'),
#      ('F', "the Ghostrider 's motorcycle")]},
#    {'response': 'I also see two eyes with strange mouths: the green is the horns, the blue the mouth, the gray an electric razor or some kind of sonic screwdriver.',
#     'noun_phrase': ['strange mouths', 'some kind of sonic screwdriver'],
#     'coordination': True,
#     'content': [('A', 'strange mouths'),
#      ('Sc', 'some kind of sonic screwdriver')],
#     'determinant': [('F', 'strange mouths'),
#      ('F', 'some kind of sonic screwdriver')]},
#    {'response': 'Two figures with a blue ponpon are liquefying, perhaps made of skin and air (pink).',
#     'noun_phrase': ['Two figures with a blue ponpon', 'air (pink)'],
#     'coordination': True,
#     'content': [('H', 'Two figures with a blue ponpon'), ('A', 'air (pink)')],
#     'determinant': [('F', 'Two figures with a blue ponpon'),
#      ('F', 'air (pink)')]},
#    {'response': 'The two ants will try to put a cap on them to stop them deflating.',
#     'noun_phrase': 'The two ants',
#     'content': 'H',
#     'determinant': 'FC',
#     'coordination': False},
#    {'response': 'Two back brushes, a hairbrush or an odd compass (orange).',
#     'noun_phrase': ['Two back brushes a hairbrush', 'an odd compass (orange)'],
#     'coordination': True,
#     'content': [('H', 'Two back brushes a hairbrush'),
#      ('A', 'an odd compass (orange)')],
#     'determinant': [('Mp', 'Two back brushes a hairbrush'),
#      ('F', 'an odd compass (orange)')]},
#    {'response': 'Finally, the two caterpillars have their astral projections coming out of their bodies.',
#     'noun_phrase': 'the two caterpillars',
#     'content': 'H',
#     'determinant': 'FC',
#     'coordination': False},
#    {'response': 'Two people supporting each other so as not to lose their balance and fall (central blue).',
#     'noun_phrase': ['Two people supporting each other so as not to lose their balance',
#      '(central blue)'],
#     'coordination': True,
#     'content': [('H',
#       'Two people supporting each other so as not to lose their balance'),
#      ('A', '(central blue)')],
#     'determinant': [('Ma',
#       'Two people supporting each other so as not to lose their balance'),
#      ('F', '(central blue)')]}]}]
